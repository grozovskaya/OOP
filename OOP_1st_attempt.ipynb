# %%
import json
from io import TextIOWrapper

# %%
import pandas as pd

# %%
from dataclasses import dataclass

# %%
import unittest
from abc import abstractmethod
import sys

# %% [markdown]
# ## Датасет Molweni
#
# https://github.com/HIT-SCIR/Molweni
#
# содержит многосторонние диалоги из Ubuntu Chat Corpus (переписки на форуме, посвящённом операционной системе Ubuntu) с разметкой в рамках SDRT - Segmented Discourse Representation Theory. Предназначен для задач Machine Reading Comprehension.
#
#
# объём: 10 000 диалогов
#
# подробнее об SDRT: каждый диалог представлен как ориентированный ациклический граф, где Узел - это высказывание; Ребро - это дискурсивная связь; Направление ребра - направление дискурсивной зависимости. Взаимосвязанные высказывания обозначаются как Arg1 и Arg2. Подход SDRT различает 16 типов дискурсивных связей. EDU считается одна реплика одного пользователя, т.е. Высказывания пользователя на части не сегментируется.

# %% [markdown]
# **Данные устроены так:**
#
# есть 3 файла json: dev-Copy1, test-Copy1, train-Copy1
#
# в каждом из них по ключу data следующая структура:
#
# по ключу title (для каждого файла значение соответсвенно dev, test или train) лежит список dialogues;
#
# в списке dialogues - словари, в каждом словаре следующие ключи:
# - edus (список EDU каждого диалога, каждое EDU - словарь с ключами text и speaker)
# - context (склеенные в одну строку элементы edus, speaker : text)
# - qas (вопросы и ответы разметчиков; у каждого вопроса есть: id; question - сам текст вопроса; answers - список кусочков текста из context (?), где есть ответ на вопрос, и answer_start - число {возможно, с какого элемента в строке context начинается ответ}; is_impossible: true/false формат, если хоть один ответ на вопрос есть, то значение false, если список answers пуст, то true)
# - relations (отношения между EDU в этом диалоге; у каждого отношения есть: x и y - Arg1 и Arg2 соответственно; type - тип отношения)

# %% [markdown]
# ## класс Molweni_into_pandas
#
# Мы хотим создать таблицу pandas, где данные представлялись бы удобно, построчно для каждого диалога (т.е. таблица со следующими столбцами: 'dialogue ID', 'context', 'EDUs', 'relations', 'QAs'). Для этого создаём класс, который предоставляет данные в удобном виде. В функции классов будет передаваться переменная - датасет Molweni в формате json. Функции класса будут читать датасет и доставать из него необходимые элементы, сразу формируя из них строки для таблицы.

# %%
def decor_exceptions_for_inint(function_init):
    def exceptions_to_wrap_around_init(self, input_name):
        try:
            function_init(self, input_name)
        except FileNotFoundError: 
            print('File named <<', 
                  input_name, '>> is not found. Please check the spelling!')         
        except ValueError:
            print('File named <<', 
                  input_name, '>> is not JSON file and cannot be accepted. Only JSON file can do!')         
        except (OSError, TypeError):
            print(input_name, ' is ', 
                  type(input_name), ''' and cannot be accepted. Should be class 'str' ''')
    return exceptions_to_wrap_around_init

# %%
def decor_for_into_pandas_lines(function_pandas_lines):
    def print_after_pandas_lines(self, some_dict):
        x = function_pandas_lines(self, some_dict)
        print('Successfully unwraped! You can call in via .pandas_data')
        return x
    return print_after_pandas_lines

# %%
def decor_exceptions_for_unfold(function_unfold):
    def exceptions_to_wrap_around_unfold(self, some_dict, some_int):
        try:
            x1, x2, x3, x4, x5 = function_unfold(self, some_dict, some_int)
            return x1, x2, x3, x4, x5
        except Exception:
            print('''Something is wrong with data itself. Make sure it's Molweni format!''')
    return exceptions_to_wrap_around_unfold

# %%
class Molweni_into_pandas:
    filename: str
    file: TextIOWrapper
    data_from_file: dict
    pandas_data: list
    
    @decor_exceptions_for_inint
    def __init__(self, input_filename: str) -> None:
        file = open(input_filename, 'r', encoding='utf-8')
        self.data_from_file = json.load(file)
        self.pandas_data = self.into_pandas_lines(self.data_from_file)
        
    @decor_for_into_pandas_lines
    def into_pandas_lines(self, data: dict) -> list:        
        raw_dialogues = data['data']['dialogues']
        unfld_data = [list(self.unfold(raw_dialogues[n], n+1)) 
                      for n in range(len(raw_dialogues))]
        return unfld_data
    
    @decor_exceptions_for_unfold
    def unfold(self, folded_dialogue: dict, number: int) -> list:
        dialogue_ID = 'd' + str(number)
        
        context = folded_dialogue['context']
        
        raw_edus = folded_dialogue['edus']
        edus_of_this_dialogue = [{'edu_ID':'d' + str(number)  + 'e' + str(y+1), 
                        'speaker':raw_edus[y]['speaker'], 
                        'text':raw_edus[y]['text']} for y in range(len(raw_edus))]
        
        raw_relations = folded_dialogue['relations']
        relations_of_this_dialogue = [{'relation_ID':'d' + str(number)  + 'r' + str(z+1), 
                                'type':raw_relations[z]['type'], 
                                'Arg1':'e' + str(raw_relations[z]['x']+1), 
                                'Arg2':'e' + str(raw_relations[z]['y']+1)} for z in range(len(raw_relations))] 

        qas = folded_dialogue['qas']
        return dialogue_ID, context, edus_of_this_dialogue, relations_of_this_dialogue, qas

# %%
mp = Molweni_into_pandas('test-Copy1.json')
# Out:
# Successfully unwraped! You can call in via .pandas_data

# %%
tabledata = mp.pandas_data

# %%
pd.DataFrame(tabledata, columns=['dialogue ID', 'context', 'EDUs', 'relations', 'QAs'])
# Out:
#    dialogue ID                                            context  \
# 0           d1  jujubee_: that i use between linux and windows...
# 1           d2  mohammadag: replace block with your dev node b...
# 2           d3  sugi: i guess there is not enough gamers here ...
# 3           d4  gnomefreak: to me it looks like its trying to ...
# 4           d5  warbler: adebo : what are you entering for the...
# 5           d6  niuq: there is any way to disable tapping from...
# 6           d7  nbx909: how do i find the address of a usb dev...
# 7           d8  cmclean: geforce4 mx 440 with agp8x ( gpu 0 de...
# 8           d9  noone: can some one help me with linux warpfor...
# 9          d10  rabiddachshund: `` button 3 '' refers to the m...
# 10         d11  bhuey: what about via command line remotely ? ...
# 11         d12  noone: can some one help me with linux warpfor...
# 12         d13  nbx909: how do i find the address of a usb dev...
# 13         d14  red_fox1: anyone have any idea why ubuntu woul...
# 14         d15  bhavi_bond: channel [ linuxmobile ] does not e...
# 15         d16  xxiao: i recall there is erlang java version e...
# 16         d17  warbler: adebo : what are you entering for the...
# 17         d18  vbabiy: yeah now i need to use something like ...
# 18         d19  renegade420: i am having a problem with users ...
# 19         d20  jujubee_: that i use between linux and windows...
# 20         d21  sugi: i guess there is not enough gamers here ...
# 21         d22  rabiddachshund: `` button 3 '' refers to the m...
# 22         d23  jujubee_: that i use between linux and windows...
# 23         d24  camer0ff: hyper_ch thats pretty much it.. i ca...
# 24         d25  jujubee_: that i use between linux and windows...
# 25         d26  a111: the flash player for your browser cy ? c...
# 26         d27  cantmountanyhd: what is that image posting sit...
# 27         d28  pianoboy3333: does anyone know how to hook up ...
# 28         d29  dirkvdbroek: i know my bit around the system ,...
# 29         d30  ljl: ! backports xfm ( xfm , see the private m...
# ..         ...                                                ...
# 70         d71  pianoboy3333: does anyone know how to hook up ...
# 71         d72  evilzx: someone else is downloading something ...
# 72         d73  technodude: can you build a tar file on a debi...
# 73         d74  cmclean: geforce4 mx 440 with agp8x ( gpu 0 de...
# 74         d75  mateusz: i removed f-spot and now when i conne...
# 75         d76  aliasrush: yeah you have any opinions on using...
# 76         d77  matthew99857: so do i need additional hardware...
# 77         d78  lasking: please install the kde development pa...
# 78         d79  mohammadag: replace block with your dev node b...
# 79         d80  techsupport: bluedusk , no , but i dont want t...
# 80         d81  nuked: ok likwidoxigen ill reboot and let you ...
# 81         d82  technodude: can you build a tar file on a debi...
# 82         d83  rabiddachshund: `` button 3 '' refers to the m...
# 83         d84  earthen: it is possable that your blue tooth h...
# 84         d85  qkslvrwolf: how do i get filepath manager to u...
# 85         d86  mohammadag: replace block with your dev node b...
# 86         d87  techsupport: bluedusk , no , but i dont want t...
# 87         d88  timfrost: gnonmefreak , lightbright , you do n...
# 88         d89  toma-: but its well worth the wait woodgrain: ...
# 89         d90  mrwes: mount shares from ubuntu server filepat...
# 90         d91  tokenekie: how do i search for commands using ...
# 91         d92  specialbuddy: well i want to know why i ca n't...
# 92         d93  nuked: ok likwidoxigen ill reboot and let you ...
# 93         d94  mohammadag: replace block with your dev node b...
# 94         d95  gopp: 01:00.0 vga compatible controller : nvid...
# 95         d96  vbabiy: yeah now i need to use something like ...
# 96         d97  noone: can some one help me with linux warpfor...
# 97         d98  earthen: it is possable that your blue tooth h...
# 98         d99  _johny: when is feisty planned to be released ...
# 99        d100  piyush: i tried sudo synaptic it says host unr...
#
#                                                  EDUs  \
# 0   [{'edu_ID': 'd1e1', 'speaker': 'JuJuBee_', 'te...
# 1   [{'edu_ID': 'd2e1', 'speaker': 'MohammadAG', '...
# 2   [{'edu_ID': 'd3e1', 'speaker': 'sugi', 'text':...
# 3   [{'edu_ID': 'd4e1', 'speaker': 'gnomefreak', '...
# 4   [{'edu_ID': 'd5e1', 'speaker': 'warbler', 'tex...
# 5   [{'edu_ID': 'd6e1', 'speaker': 'niuq', 'text':...
# 6   [{'edu_ID': 'd7e1', 'speaker': 'nbx909', 'text...
# 7   [{'edu_ID': 'd8e1', 'speaker': 'Cmclean', 'tex...
# 8   [{'edu_ID': 'd9e1', 'speaker': 'noone', 'text'...
# 9   [{'edu_ID': 'd10e1', 'speaker': 'rabiddachshun...
# 10  [{'edu_ID': 'd11e1', 'speaker': 'bhuey', 'text...
# 11  [{'edu_ID': 'd12e1', 'speaker': 'noone', 'text...
# 12  [{'edu_ID': 'd13e1', 'speaker': 'nbx909', 'tex...
# 13  [{'edu_ID': 'd14e1', 'speaker': 'reD_Fox1', 't...
# 14  [{'edu_ID': 'd15e1', 'speaker': 'bhavi_bond', ...
# 15  [{'edu_ID': 'd16e1', 'speaker': 'xxiao', 'text...
# 16  [{'edu_ID': 'd17e1', 'speaker': 'warbler', 'te...
# 17  [{'edu_ID': 'd18e1', 'speaker': 'vbabiy', 'tex...
# 18  [{'edu_ID': 'd19e1', 'speaker': 'renegade420',...
# 19  [{'edu_ID': 'd20e1', 'speaker': 'JuJuBee_', 't...
# 20  [{'edu_ID': 'd21e1', 'speaker': 'sugi', 'text'...
# 21  [{'edu_ID': 'd22e1', 'speaker': 'rabiddachshun...
# 22  [{'edu_ID': 'd23e1', 'speaker': 'JuJuBee_', 't...
# 23  [{'edu_ID': 'd24e1', 'speaker': 'camer0ff', 't...
# 24  [{'edu_ID': 'd25e1', 'speaker': 'JuJuBee_', 't...
# 25  [{'edu_ID': 'd26e1', 'speaker': 'a111', 'text'...
# 26  [{'edu_ID': 'd27e1', 'speaker': 'cantmountanyh...
# 27  [{'edu_ID': 'd28e1', 'speaker': 'pianoboy3333'...
# 28  [{'edu_ID': 'd29e1', 'speaker': 'dirkvdbroek',...
# 29  [{'edu_ID': 'd30e1', 'speaker': 'LjL', 'text':...
# ..                                                ...
# 70  [{'edu_ID': 'd71e1', 'speaker': 'pianoboy3333'...
# 71  [{'edu_ID': 'd72e1', 'speaker': 'EvilZx', 'tex...
# 72  [{'edu_ID': 'd73e1', 'speaker': 'technodude', ...
# 73  [{'edu_ID': 'd74e1', 'speaker': 'Cmclean', 'te...
# 74  [{'edu_ID': 'd75e1', 'speaker': 'mateusz', 'te...
# 75  [{'edu_ID': 'd76e1', 'speaker': 'aliasrush', '...
# 76  [{'edu_ID': 'd77e1', 'speaker': 'matthew99857'...
# 77  [{'edu_ID': 'd78e1', 'speaker': 'lasking', 'te...
# 78  [{'edu_ID': 'd79e1', 'speaker': 'MohammadAG', ...
# 79  [{'edu_ID': 'd80e1', 'speaker': 'techsupport',...
# 80  [{'edu_ID': 'd81e1', 'speaker': 'Nuked', 'text...
# 81  [{'edu_ID': 'd82e1', 'speaker': 'technodude', ...
# 82  [{'edu_ID': 'd83e1', 'speaker': 'rabiddachshun...
# 83  [{'edu_ID': 'd84e1', 'speaker': 'earthen', 'te...
# 84  [{'edu_ID': 'd85e1', 'speaker': 'qkslvrwolf', ...
# 85  [{'edu_ID': 'd86e1', 'speaker': 'MohammadAG', ...
# 86  [{'edu_ID': 'd87e1', 'speaker': 'techsupport',...
# 87  [{'edu_ID': 'd88e1', 'speaker': 'timfrost', 't...
# 88  [{'edu_ID': 'd89e1', 'speaker': 'Toma-', 'text...
# 89  [{'edu_ID': 'd90e1', 'speaker': 'mrwes', 'text...
# 90  [{'edu_ID': 'd91e1', 'speaker': 'Tokenekie', '...
# 91  [{'edu_ID': 'd92e1', 'speaker': 'specialbuddy'...
# 92  [{'edu_ID': 'd93e1', 'speaker': 'Nuked', 'text...
# 93  [{'edu_ID': 'd94e1', 'speaker': 'MohammadAG', ...
# 94  [{'edu_ID': 'd95e1', 'speaker': 'gopp', 'text'...
# 95  [{'edu_ID': 'd96e1', 'speaker': 'vbabiy', 'tex...
# 96  [{'edu_ID': 'd97e1', 'speaker': 'noone', 'text...
# 97  [{'edu_ID': 'd98e1', 'speaker': 'earthen', 'te...
# 98  [{'edu_ID': 'd99e1', 'speaker': '_Johny', 'tex...
# 99  [{'edu_ID': 'd100e1', 'speaker': 'piyush', 'te...
#
#                                             relations  \
# 0   [{'relation_ID': 'd1r1', 'type': 'Clarificatio...
# 1   [{'relation_ID': 'd2r1', 'type': 'Narration', ...
# 2   [{'relation_ID': 'd3r1', 'type': 'Clarificatio...
# 3   [{'relation_ID': 'd4r1', 'type': 'Acknowledgem...
# 4   [{'relation_ID': 'd5r1', 'type': 'QAP', 'Arg1'...
# 5   [{'relation_ID': 'd6r1', 'type': 'Clarificatio...
# 6   [{'relation_ID': 'd7r1', 'type': 'Q-Elab', 'Ar...
# 7   [{'relation_ID': 'd8r1', 'type': 'Narration', ...
# 8   [{'relation_ID': 'd9r1', 'type': 'Q-Elab', 'Ar...
# 9   [{'relation_ID': 'd10r1', 'type': 'QAP', 'Arg1...
# 10  [{'relation_ID': 'd11r1', 'type': 'QAP', 'Arg1...
# 11  [{'relation_ID': 'd12r1', 'type': 'Q-Elab', 'A...
# 12  [{'relation_ID': 'd13r1', 'type': 'QAP', 'Arg1...
# 13  [{'relation_ID': 'd14r1', 'type': 'Q-Elab', 'A...
# 14  [{'relation_ID': 'd15r1', 'type': 'Result', 'A...
# 15  [{'relation_ID': 'd16r1', 'type': 'Narration',...
# 16  [{'relation_ID': 'd17r1', 'type': 'QAP', 'Arg1...
# 17  [{'relation_ID': 'd18r1', 'type': 'Narration',...
# 18  [{'relation_ID': 'd19r1', 'type': 'Clarificati...
# 19  [{'relation_ID': 'd20r1', 'type': 'Clarificati...
# 20  [{'relation_ID': 'd21r1', 'type': 'Clarificati...
# 21  [{'relation_ID': 'd22r1', 'type': 'QAP', 'Arg1...
# 22  [{'relation_ID': 'd23r1', 'type': 'Clarificati...
# 23  [{'relation_ID': 'd24r1', 'type': 'QAP', 'Arg1...
# 24  [{'relation_ID': 'd25r1', 'type': 'Clarificati...
# 25  [{'relation_ID': 'd26r1', 'type': 'QAP', 'Arg1...
# 26  [{'relation_ID': 'd27r1', 'type': 'Clarificati...
# 27  [{'relation_ID': 'd28r1', 'type': 'QAP', 'Arg1...
# 28  [{'relation_ID': 'd29r1', 'type': 'Clarificati...
# 29  [{'relation_ID': 'd30r1', 'type': 'Comment', '...
# ..                                                ...
# 70  [{'relation_ID': 'd71r1', 'type': 'QAP', 'Arg1...
# 71  [{'relation_ID': 'd72r1', 'type': 'Comment', '...
# 72  [{'relation_ID': 'd73r1', 'type': 'QAP', 'Arg1...
# 73  [{'relation_ID': 'd74r1', 'type': 'Comment', '...
# 74  [{'relation_ID': 'd75r1', 'type': 'Clarificati...
# 75  [{'relation_ID': 'd76r1', 'type': 'Narration',...
# 76  [{'relation_ID': 'd77r1', 'type': 'Q-Elab', 'A...
# 77  [{'relation_ID': 'd78r1', 'type': 'QAP', 'Arg1...
# 78  [{'relation_ID': 'd79r1', 'type': 'Narration',...
# 79  [{'relation_ID': 'd80r1', 'type': 'Comment', '...
# 80  [{'relation_ID': 'd81r1', 'type': 'Clarificati...
# 81  [{'relation_ID': 'd82r1', 'type': 'QAP', 'Arg1...
# 82  [{'relation_ID': 'd83r1', 'type': 'QAP', 'Arg1...
# 83  [{'relation_ID': 'd84r1', 'type': 'Background'...
# 84  [{'relation_ID': 'd85r1', 'type': 'QAP', 'Arg1...
# 85  [{'relation_ID': 'd86r1', 'type': 'Narration',...
# 86  [{'relation_ID': 'd87r1', 'type': 'Comment', '...
# 87  [{'relation_ID': 'd88r1', 'type': 'Clarificati...
# 88  [{'relation_ID': 'd89r1', 'type': 'Clarificati...
# 89  [{'relation_ID': 'd90r1', 'type': 'QAP', 'Arg1...
# 90  [{'relation_ID': 'd91r1', 'type': 'QAP', 'Arg1...
# 91  [{'relation_ID': 'd92r1', 'type': 'Clarificati...
# 92  [{'relation_ID': 'd93r1', 'type': 'Clarificati...
# 93  [{'relation_ID': 'd94r1', 'type': 'Narration',...
# 94  [{'relation_ID': 'd95r1', 'type': 'Comment', '...
# 95  [{'relation_ID': 'd96r1', 'type': 'Narration',...
# 96  [{'relation_ID': 'd97r1', 'type': 'Q-Elab', 'A...
# 97  [{'relation_ID': 'd98r1', 'type': 'Background'...
# 98  [{'relation_ID': 'd99r1', 'type': 'QAP', 'Arg1...
# 99  [{'relation_ID': 'd100r1', 'type': 'Clarificat...
#
#                                                   QAs
# 0   [{'question': 'Where does JuJuBee_ use ?', 'id...
# 1   [{'question': 'What can replace  block ?', 'id...
# 2   [{'question': 'What is sugi going to do ?', 'i...
# 3   [{'question': 'Who opened the repositories？', ...
# 4   [{'question': 'What was warbler entering for t...
# 5   [{'question': 'What does niuq want to do ?', '...
# 6   [{'question': 'What does nbx909 want to do ?',...
# 7   [{'question': 'What does the command you gave ...
# 8   [{'question': 'What is everybody using here ?'...
# 9   [{'question': 'What refers to the clicking of ...
# 10  [{'question': 'What does Flannel think ?', 'id...
# 11  [{'question': 'What is everybody using here ?'...
# 12  [{'question': 'What does nbx909 want to do ?',...
# 13  [{'question': 'Who thinks it will boot after h...
# 14  [{'question': 'What does it show when bhavi_bo...
# 15  [{'question': 'What does xxiao recall ?', 'id'...
# 16  [{'question': 'What was warbler entering for t...
# 17  [{'question': 'What is the right version？', 'i...
# 18  [{'question': 'What problem does renegade420 h...
# 19  [{'question': 'Where does JuJuBee_ use ?', 'id...
# 20  [{'question': 'What is sugi going to do ?', 'i...
# 21  [{'question': 'What refers to the clicking of ...
# 22  [{'question': 'Where does JuJuBee_ use ?', 'id...
# 23  [{'question': 'What used to have dns issues wi...
# 24  [{'question': 'Where does JuJuBee_ use ?', 'id...
# 25  [{'question': 'What does CyborgSmurf want to d...
# 26  [{'question': 'What is that image posting site...
# 27  [{'question': 'How to hook up a monitor？', 'id...
# 28  [{'question': 'Who used ccooke's xorg.conf yes...
# 29  [{'question': 'Which version does xfm want to ...
# ..                                                ...
# 70  [{'question': 'How to hook up a monitor？', 'id...
# 71  [{'question': 'What does _Zeus_ suggest first？...
# 72  [{'question': 'Where can build a tar file ?', ...
# 73  [{'question': 'What does the command you gave ...
# 74  [{'question': 'What did mateusz remove ?', 'id...
# 75  [{'question': 'What does petr4's server have ?...
# 76  [{'question': 'What does ikonia use the disk ?...
# 77  [{'question': 'How to get instruction ?', 'id'...
# 78  [{'question': 'What can replace  block ?', 'id...
# 79  [{'question': 'What does BlueEagle think about...
# 80  [{'question': 'What does Likwidoxigen keep doi...
# 81  [{'question': 'Where can build a tar file ?', ...
# 82  [{'question': 'What refers to the clicking of ...
# 83  [{'question': 'What is just the standard hardw...
# 84  [{'question': 'How to get a FILEPATH manager ?...
# 85  [{'question': 'What can replace the block ?', ...
# 86  [{'question': 'Why can permission deny lol not...
# 87  [{'question': 'Who puts au on all except for s...
# 88  [{'question': 'What does woodgrain have ?', 'i...
# 89  [{'question': 'Where to mount shares ?', 'id':...
# 90  [{'question': 'What does Tokenekie want to do ...
# 91  [{'question': 'What happened to specialbuddy ?...
# 92  [{'question': 'What should be the address ?', ...
# 93  [{'question': 'What can replace block ?', 'id'...
# 94  [{'question': 'What is for installing things ?...
# 95  [{'question': 'What is the right version？', 'i...
# 96  [{'question': 'What is everybody using here ?'...
# 97  [{'question': 'What is just the standard hardw...
# 98  [{'question': 'What has Gabz read？', 'id': '01...
# 99  [{'question': 'Which mode is ip in ?', 'id': '...
#
# [100 rows x 5 columns]

# %% [markdown]
# Красиво, но можно лучше

# %% [markdown]
# ## класс-наследник Molweni_into_beautiful_pandas (переопределение метода)
#
# Всё то же самое, но без лишних скобочек от словарей и списков. Для EDU и relations в рамках одной ячейки - красивое построчное выведение по одному. Для этого наследуем всё, но переопределим функцию into_pandas_lines.
#
# P.S. для столбика Q&A понадобится разработать отдельную систему выведения

# %%
def to_overcome_QA_problem(beauty_func):
    def QA_problem_wraping(self, some_list):
        try:
            results = beauty_func(self, some_list)
            return results
        except TypeError:
            return some_list
    return QA_problem_wraping

# %%
class Molweni_into_beautiful_pandas(Molweni_into_pandas):
    
    @decor_for_into_pandas_lines
    def into_pandas_lines(self, data: dict)-> list:
        unwr_data = []
        raw_dialogues = data['data']['dialogues']
        for n in range(len(raw_dialogues)):
            (dialogue_ID, 
             context, 
             edus_of_this_dialogue,
            relations_of_this_dialogue, 
             qas) = self.unfold(raw_dialogues[n], n+1)
            new_line = [dialogue_ID, 
                        context, 
                        self.beauty_maker(edus_of_this_dialogue), 
                        self.beauty_maker(relations_of_this_dialogue), 
                        self.beauty_maker(qas)]
            unwr_data.append(new_line)          
        return unwr_data
    
    @to_overcome_QA_problem
    def beauty_maker(self, in_work_list: list) -> list:
        list_of_new_ones = []
        for one in in_work_list:
            parts = [key + ': ' + value for key, value in one.items()]
            new_one = ' -> '.join(parts)
            list_of_new_ones.append(new_one)
        beautiful_new_ones = '\n'.join(list_of_new_ones)
        return beautiful_new_ones

# %%
mb = Molweni_into_beautiful_pandas('test-Copy1.json')
# Out:
# Successfully unwraped! You can call in via .pandas_data

# %%
tabledata_vol2 = mb.pandas_data

# %%
pd.DataFrame(tabledata_vol2, columns=['dialogue ID', 'context', 'EDUs', 'relations', 'QAs'])
# Out:
#    dialogue ID                                            context  \
# 0           d1  jujubee_: that i use between linux and windows...
# 1           d2  mohammadag: replace block with your dev node b...
# 2           d3  sugi: i guess there is not enough gamers here ...
# 3           d4  gnomefreak: to me it looks like its trying to ...
# 4           d5  warbler: adebo : what are you entering for the...
# 5           d6  niuq: there is any way to disable tapping from...
# 6           d7  nbx909: how do i find the address of a usb dev...
# 7           d8  cmclean: geforce4 mx 440 with agp8x ( gpu 0 de...
# 8           d9  noone: can some one help me with linux warpfor...
# 9          d10  rabiddachshund: `` button 3 '' refers to the m...
# 10         d11  bhuey: what about via command line remotely ? ...
# 11         d12  noone: can some one help me with linux warpfor...
# 12         d13  nbx909: how do i find the address of a usb dev...
# 13         d14  red_fox1: anyone have any idea why ubuntu woul...
# 14         d15  bhavi_bond: channel [ linuxmobile ] does not e...
# 15         d16  xxiao: i recall there is erlang java version e...
# 16         d17  warbler: adebo : what are you entering for the...
# 17         d18  vbabiy: yeah now i need to use something like ...
# 18         d19  renegade420: i am having a problem with users ...
# 19         d20  jujubee_: that i use between linux and windows...
# 20         d21  sugi: i guess there is not enough gamers here ...
# 21         d22  rabiddachshund: `` button 3 '' refers to the m...
# 22         d23  jujubee_: that i use between linux and windows...
# 23         d24  camer0ff: hyper_ch thats pretty much it.. i ca...
# 24         d25  jujubee_: that i use between linux and windows...
# 25         d26  a111: the flash player for your browser cy ? c...
# 26         d27  cantmountanyhd: what is that image posting sit...
# 27         d28  pianoboy3333: does anyone know how to hook up ...
# 28         d29  dirkvdbroek: i know my bit around the system ,...
# 29         d30  ljl: ! backports xfm ( xfm , see the private m...
# ..         ...                                                ...
# 70         d71  pianoboy3333: does anyone know how to hook up ...
# 71         d72  evilzx: someone else is downloading something ...
# 72         d73  technodude: can you build a tar file on a debi...
# 73         d74  cmclean: geforce4 mx 440 with agp8x ( gpu 0 de...
# 74         d75  mateusz: i removed f-spot and now when i conne...
# 75         d76  aliasrush: yeah you have any opinions on using...
# 76         d77  matthew99857: so do i need additional hardware...
# 77         d78  lasking: please install the kde development pa...
# 78         d79  mohammadag: replace block with your dev node b...
# 79         d80  techsupport: bluedusk , no , but i dont want t...
# 80         d81  nuked: ok likwidoxigen ill reboot and let you ...
# 81         d82  technodude: can you build a tar file on a debi...
# 82         d83  rabiddachshund: `` button 3 '' refers to the m...
# 83         d84  earthen: it is possable that your blue tooth h...
# 84         d85  qkslvrwolf: how do i get filepath manager to u...
# 85         d86  mohammadag: replace block with your dev node b...
# 86         d87  techsupport: bluedusk , no , but i dont want t...
# 87         d88  timfrost: gnonmefreak , lightbright , you do n...
# 88         d89  toma-: but its well worth the wait woodgrain: ...
# 89         d90  mrwes: mount shares from ubuntu server filepat...
# 90         d91  tokenekie: how do i search for commands using ...
# 91         d92  specialbuddy: well i want to know why i ca n't...
# 92         d93  nuked: ok likwidoxigen ill reboot and let you ...
# 93         d94  mohammadag: replace block with your dev node b...
# 94         d95  gopp: 01:00.0 vga compatible controller : nvid...
# 95         d96  vbabiy: yeah now i need to use something like ...
# 96         d97  noone: can some one help me with linux warpfor...
# 97         d98  earthen: it is possable that your blue tooth h...
# 98         d99  _johny: when is feisty planned to be released ...
# 99        d100  piyush: i tried sudo synaptic it says host unr...
#
#                                                  EDUs  \
# 0   edu_ID: d1e1 -> speaker: JuJuBee_ -> text: tha...
# 1   edu_ID: d2e1 -> speaker: MohammadAG -> text: r...
# 2   edu_ID: d3e1 -> speaker: sugi -> text: i guess...
# 3   edu_ID: d4e1 -> speaker: gnomefreak -> text: t...
# 4   edu_ID: d5e1 -> speaker: warbler -> text: adeb...
# 5   edu_ID: d6e1 -> speaker: niuq -> text: there i...
# 6   edu_ID: d7e1 -> speaker: nbx909 -> text: how d...
# 7   edu_ID: d8e1 -> speaker: Cmclean -> text: gefo...
# 8   edu_ID: d9e1 -> speaker: noone -> text: can so...
# 9   edu_ID: d10e1 -> speaker: rabiddachshund -> te...
# 10  edu_ID: d11e1 -> speaker: bhuey -> text: what ...
# 11  edu_ID: d12e1 -> speaker: noone -> text: can s...
# 12  edu_ID: d13e1 -> speaker: nbx909 -> text: how ...
# 13  edu_ID: d14e1 -> speaker: reD_Fox1 -> text: an...
# 14  edu_ID: d15e1 -> speaker: bhavi_bond -> text: ...
# 15  edu_ID: d16e1 -> speaker: xxiao -> text: i rec...
# 16  edu_ID: d17e1 -> speaker: warbler -> text: ade...
# 17  edu_ID: d18e1 -> speaker: vbabiy -> text: yeah...
# 18  edu_ID: d19e1 -> speaker: renegade420 -> text:...
# 19  edu_ID: d20e1 -> speaker: JuJuBee_ -> text: th...
# 20  edu_ID: d21e1 -> speaker: sugi -> text: i gues...
# 21  edu_ID: d22e1 -> speaker: rabiddachshund -> te...
# 22  edu_ID: d23e1 -> speaker: JuJuBee_ -> text: th...
# 23  edu_ID: d24e1 -> speaker: camer0ff -> text: hy...
# 24  edu_ID: d25e1 -> speaker: JuJuBee_ -> text: th...
# 25  edu_ID: d26e1 -> speaker: a111 -> text: the fl...
# 26  edu_ID: d27e1 -> speaker: cantmountanyhd -> te...
# 27  edu_ID: d28e1 -> speaker: pianoboy3333 -> text...
# 28  edu_ID: d29e1 -> speaker: dirkvdbroek -> text:...
# 29  edu_ID: d30e1 -> speaker: LjL -> text: ! backp...
# ..                                                ...
# 70  edu_ID: d71e1 -> speaker: pianoboy3333 -> text...
# 71  edu_ID: d72e1 -> speaker: EvilZx -> text: some...
# 72  edu_ID: d73e1 -> speaker: technodude -> text: ...
# 73  edu_ID: d74e1 -> speaker: Cmclean -> text: gef...
# 74  edu_ID: d75e1 -> speaker: mateusz -> text: i r...
# 75  edu_ID: d76e1 -> speaker: aliasrush -> text: y...
# 76  edu_ID: d77e1 -> speaker: matthew99857 -> text...
# 77  edu_ID: d78e1 -> speaker: lasking -> text: ple...
# 78  edu_ID: d79e1 -> speaker: MohammadAG -> text: ...
# 79  edu_ID: d80e1 -> speaker: techsupport -> text:...
# 80  edu_ID: d81e1 -> speaker: Nuked -> text: ok li...
# 81  edu_ID: d82e1 -> speaker: technodude -> text: ...
# 82  edu_ID: d83e1 -> speaker: rabiddachshund -> te...
# 83  edu_ID: d84e1 -> speaker: earthen -> text: it ...
# 84  edu_ID: d85e1 -> speaker: qkslvrwolf -> text: ...
# 85  edu_ID: d86e1 -> speaker: MohammadAG -> text: ...
# 86  edu_ID: d87e1 -> speaker: techsupport -> text:...
# 87  edu_ID: d88e1 -> speaker: timfrost -> text: gn...
# 88  edu_ID: d89e1 -> speaker: Toma- -> text: but i...
# 89  edu_ID: d90e1 -> speaker: mrwes -> text: mount...
# 90  edu_ID: d91e1 -> speaker: Tokenekie -> text: h...
# 91  edu_ID: d92e1 -> speaker: specialbuddy -> text...
# 92  edu_ID: d93e1 -> speaker: Nuked -> text: ok li...
# 93  edu_ID: d94e1 -> speaker: MohammadAG -> text: ...
# 94  edu_ID: d95e1 -> speaker: gopp -> text: 01:00....
# 95  edu_ID: d96e1 -> speaker: vbabiy -> text: yeah...
# 96  edu_ID: d97e1 -> speaker: noone -> text: can s...
# 97  edu_ID: d98e1 -> speaker: earthen -> text: it ...
# 98  edu_ID: d99e1 -> speaker: _Johny -> text: when...
# 99  edu_ID: d100e1 -> speaker: piyush -> text: i t...
#
#                                             relations  \
# 0   relation_ID: d1r1 -> type: Clarification_quest...
# 1   relation_ID: d2r1 -> type: Narration -> Arg1: ...
# 2   relation_ID: d3r1 -> type: Clarification_quest...
# 3   relation_ID: d4r1 -> type: Acknowledgement -> ...
# 4   relation_ID: d5r1 -> type: QAP -> Arg1: e1 -> ...
# 5   relation_ID: d6r1 -> type: Clarification_quest...
# 6   relation_ID: d7r1 -> type: Q-Elab -> Arg1: e1 ...
# 7   relation_ID: d8r1 -> type: Narration -> Arg1: ...
# 8   relation_ID: d9r1 -> type: Q-Elab -> Arg1: e1 ...
# 9   relation_ID: d10r1 -> type: QAP -> Arg1: e1 ->...
# 10  relation_ID: d11r1 -> type: QAP -> Arg1: e1 ->...
# 11  relation_ID: d12r1 -> type: Q-Elab -> Arg1: e1...
# 12  relation_ID: d13r1 -> type: QAP -> Arg1: e1 ->...
# 13  relation_ID: d14r1 -> type: Q-Elab -> Arg1: e1...
# 14  relation_ID: d15r1 -> type: Result -> Arg1: e1...
# 15  relation_ID: d16r1 -> type: Narration -> Arg1:...
# 16  relation_ID: d17r1 -> type: QAP -> Arg1: e1 ->...
# 17  relation_ID: d18r1 -> type: Narration -> Arg1:...
# 18  relation_ID: d19r1 -> type: Clarification_ques...
# 19  relation_ID: d20r1 -> type: Clarification_ques...
# 20  relation_ID: d21r1 -> type: Clarification_ques...
# 21  relation_ID: d22r1 -> type: QAP -> Arg1: e1 ->...
# 22  relation_ID: d23r1 -> type: Clarification_ques...
# 23  relation_ID: d24r1 -> type: QAP -> Arg1: e1 ->...
# 24  relation_ID: d25r1 -> type: Clarification_ques...
# 25  relation_ID: d26r1 -> type: QAP -> Arg1: e1 ->...
# 26  relation_ID: d27r1 -> type: Clarification_ques...
# 27  relation_ID: d28r1 -> type: QAP -> Arg1: e1 ->...
# 28  relation_ID: d29r1 -> type: Clarification_ques...
# 29  relation_ID: d30r1 -> type: Comment -> Arg1: e...
# ..                                                ...
# 70  relation_ID: d71r1 -> type: QAP -> Arg1: e1 ->...
# 71  relation_ID: d72r1 -> type: Comment -> Arg1: e...
# 72  relation_ID: d73r1 -> type: QAP -> Arg1: e1 ->...
# 73  relation_ID: d74r1 -> type: Comment -> Arg1: e...
# 74  relation_ID: d75r1 -> type: Clarification_ques...
# 75  relation_ID: d76r1 -> type: Narration -> Arg1:...
# 76  relation_ID: d77r1 -> type: Q-Elab -> Arg1: e1...
# 77  relation_ID: d78r1 -> type: QAP -> Arg1: e1 ->...
# 78  relation_ID: d79r1 -> type: Narration -> Arg1:...
# 79  relation_ID: d80r1 -> type: Comment -> Arg1: e...
# 80  relation_ID: d81r1 -> type: Clarification_ques...
# 81  relation_ID: d82r1 -> type: QAP -> Arg1: e1 ->...
# 82  relation_ID: d83r1 -> type: QAP -> Arg1: e1 ->...
# 83  relation_ID: d84r1 -> type: Background -> Arg1...
# 84  relation_ID: d85r1 -> type: QAP -> Arg1: e1 ->...
# 85  relation_ID: d86r1 -> type: Narration -> Arg1:...
# 86  relation_ID: d87r1 -> type: Comment -> Arg1: e...
# 87  relation_ID: d88r1 -> type: Clarification_ques...
# 88  relation_ID: d89r1 -> type: Clarification_ques...
# 89  relation_ID: d90r1 -> type: QAP -> Arg1: e1 ->...
# 90  relation_ID: d91r1 -> type: QAP -> Arg1: e1 ->...
# 91  relation_ID: d92r1 -> type: Clarification_ques...
# 92  relation_ID: d93r1 -> type: Clarification_ques...
# 93  relation_ID: d94r1 -> type: Narration -> Arg1:...
# 94  relation_ID: d95r1 -> type: Comment -> Arg1: e...
# 95  relation_ID: d96r1 -> type: Narration -> Arg1:...
# 96  relation_ID: d97r1 -> type: Q-Elab -> Arg1: e1...
# 97  relation_ID: d98r1 -> type: Background -> Arg1...
# 98  relation_ID: d99r1 -> type: QAP -> Arg1: e1 ->...
# 99  relation_ID: d100r1 -> type: Clarification_que...
#
#                                                   QAs
# 0   [{'question': 'Where does JuJuBee_ use ?', 'id...
# 1   [{'question': 'What can replace  block ?', 'id...
# 2   [{'question': 'What is sugi going to do ?', 'i...
# 3   [{'question': 'Who opened the repositories？', ...
# 4   [{'question': 'What was warbler entering for t...
# 5   [{'question': 'What does niuq want to do ?', '...
# 6   [{'question': 'What does nbx909 want to do ?',...
# 7   [{'question': 'What does the command you gave ...
# 8   [{'question': 'What is everybody using here ?'...
# 9   [{'question': 'What refers to the clicking of ...
# 10  [{'question': 'What does Flannel think ?', 'id...
# 11  [{'question': 'What is everybody using here ?'...
# 12  [{'question': 'What does nbx909 want to do ?',...
# 13  [{'question': 'Who thinks it will boot after h...
# 14  [{'question': 'What does it show when bhavi_bo...
# 15  [{'question': 'What does xxiao recall ?', 'id'...
# 16  [{'question': 'What was warbler entering for t...
# 17  [{'question': 'What is the right version？', 'i...
# 18  [{'question': 'What problem does renegade420 h...
# 19  [{'question': 'Where does JuJuBee_ use ?', 'id...
# 20  [{'question': 'What is sugi going to do ?', 'i...
# 21  [{'question': 'What refers to the clicking of ...
# 22  [{'question': 'Where does JuJuBee_ use ?', 'id...
# 23  [{'question': 'What used to have dns issues wi...
# 24  [{'question': 'Where does JuJuBee_ use ?', 'id...
# 25  [{'question': 'What does CyborgSmurf want to d...
# 26  [{'question': 'What is that image posting site...
# 27  [{'question': 'How to hook up a monitor？', 'id...
# 28  [{'question': 'Who used ccooke's xorg.conf yes...
# 29  [{'question': 'Which version does xfm want to ...
# ..                                                ...
# 70  [{'question': 'How to hook up a monitor？', 'id...
# 71  [{'question': 'What does _Zeus_ suggest first？...
# 72  [{'question': 'Where can build a tar file ?', ...
# 73  [{'question': 'What does the command you gave ...
# 74  [{'question': 'What did mateusz remove ?', 'id...
# 75  [{'question': 'What does petr4's server have ?...
# 76  [{'question': 'What does ikonia use the disk ?...
# 77  [{'question': 'How to get instruction ?', 'id'...
# 78  [{'question': 'What can replace  block ?', 'id...
# 79  [{'question': 'What does BlueEagle think about...
# 80  [{'question': 'What does Likwidoxigen keep doi...
# 81  [{'question': 'Where can build a tar file ?', ...
# 82  [{'question': 'What refers to the clicking of ...
# 83  [{'question': 'What is just the standard hardw...
# 84  [{'question': 'How to get a FILEPATH manager ?...
# 85  [{'question': 'What can replace the block ?', ...
# 86  [{'question': 'Why can permission deny lol not...
# 87  [{'question': 'Who puts au on all except for s...
# 88  [{'question': 'What does woodgrain have ?', 'i...
# 89  [{'question': 'Where to mount shares ?', 'id':...
# 90  [{'question': 'What does Tokenekie want to do ...
# 91  [{'question': 'What happened to specialbuddy ?...
# 92  [{'question': 'What should be the address ?', ...
# 93  [{'question': 'What can replace block ?', 'id'...
# 94  [{'question': 'What is for installing things ?...
# 95  [{'question': 'What is the right version？', 'i...
# 96  [{'question': 'What is everybody using here ?'...
# 97  [{'question': 'What is just the standard hardw...
# 98  [{'question': 'What has Gabz read？', 'id': '01...
# 99  [{'question': 'Which mode is ip in ?', 'id': '...
#
# [100 rows x 5 columns]

# %% [markdown]
# ## класс-наследник для Q&A (расширение метода)
#
# А теперь мы хотим, не меняя исходного кода, добавить возможность точно так же красиво оформлять данные столбика Q&A.

# %%
def QA_wraper_for_beauty_maker(beauty_maker_func):
    def the_QAwraping(self, some_list):
        try:
            bno = beauty_maker_func(self, some_list)
            return bno
        except TypeError:
            list_of_excepted_ones = []
            for one in some_list:
                excepted_parts = []
                for one_key, one_value in one.items():
                    if type(one_value) == list and len(one_value) != 0:
                        for inner_key, inner_value in one_value[0].items():
                            inner_part = inner_key + ': ' + str(inner_value)
                            excepted_parts.append(inner_part)
                    else:
                        part = one_key + ': ' + str(one_value)
                        excepted_parts.append(part)
                new_one = ' -> '.join(excepted_parts)
                list_of_excepted_ones.append(new_one)
            beautiful_new_excepted_ones = '\n'.join(list_of_excepted_ones)
            return(beautiful_new_excepted_ones)
    return the_QAwraping

# %%
class Molweni_into_pandas_QA_edition(Molweni_into_beautiful_pandas):
        
    @QA_wraper_for_beauty_maker
    def beauty_maker(self, in_work_list: list) -> list:
        return super().beauty_maker(self, in_work_list)

# %%
mqa = Molweni_into_pandas_QA_edition('test-Copy1.json')
# Out:
# Successfully unwraped! You can call in via .pandas_data

# %%
tabledata_vol3 = mqa.pandas_data

# %%
pd.DataFrame(tabledata_vol3, columns=['dialogue ID', 'context', 'EDUs', 'relations', 'QAs'])
# Out:
#    dialogue ID                                            context  \
# 0           d1  jujubee_: that i use between linux and windows...
# 1           d2  mohammadag: replace block with your dev node b...
# 2           d3  sugi: i guess there is not enough gamers here ...
# 3           d4  gnomefreak: to me it looks like its trying to ...
# 4           d5  warbler: adebo : what are you entering for the...
# 5           d6  niuq: there is any way to disable tapping from...
# 6           d7  nbx909: how do i find the address of a usb dev...
# 7           d8  cmclean: geforce4 mx 440 with agp8x ( gpu 0 de...
# 8           d9  noone: can some one help me with linux warpfor...
# 9          d10  rabiddachshund: `` button 3 '' refers to the m...
# 10         d11  bhuey: what about via command line remotely ? ...
# 11         d12  noone: can some one help me with linux warpfor...
# 12         d13  nbx909: how do i find the address of a usb dev...
# 13         d14  red_fox1: anyone have any idea why ubuntu woul...
# 14         d15  bhavi_bond: channel [ linuxmobile ] does not e...
# 15         d16  xxiao: i recall there is erlang java version e...
# 16         d17  warbler: adebo : what are you entering for the...
# 17         d18  vbabiy: yeah now i need to use something like ...
# 18         d19  renegade420: i am having a problem with users ...
# 19         d20  jujubee_: that i use between linux and windows...
# 20         d21  sugi: i guess there is not enough gamers here ...
# 21         d22  rabiddachshund: `` button 3 '' refers to the m...
# 22         d23  jujubee_: that i use between linux and windows...
# 23         d24  camer0ff: hyper_ch thats pretty much it.. i ca...
# 24         d25  jujubee_: that i use between linux and windows...
# 25         d26  a111: the flash player for your browser cy ? c...
# 26         d27  cantmountanyhd: what is that image posting sit...
# 27         d28  pianoboy3333: does anyone know how to hook up ...
# 28         d29  dirkvdbroek: i know my bit around the system ,...
# 29         d30  ljl: ! backports xfm ( xfm , see the private m...
# ..         ...                                                ...
# 70         d71  pianoboy3333: does anyone know how to hook up ...
# 71         d72  evilzx: someone else is downloading something ...
# 72         d73  technodude: can you build a tar file on a debi...
# 73         d74  cmclean: geforce4 mx 440 with agp8x ( gpu 0 de...
# 74         d75  mateusz: i removed f-spot and now when i conne...
# 75         d76  aliasrush: yeah you have any opinions on using...
# 76         d77  matthew99857: so do i need additional hardware...
# 77         d78  lasking: please install the kde development pa...
# 78         d79  mohammadag: replace block with your dev node b...
# 79         d80  techsupport: bluedusk , no , but i dont want t...
# 80         d81  nuked: ok likwidoxigen ill reboot and let you ...
# 81         d82  technodude: can you build a tar file on a debi...
# 82         d83  rabiddachshund: `` button 3 '' refers to the m...
# 83         d84  earthen: it is possable that your blue tooth h...
# 84         d85  qkslvrwolf: how do i get filepath manager to u...
# 85         d86  mohammadag: replace block with your dev node b...
# 86         d87  techsupport: bluedusk , no , but i dont want t...
# 87         d88  timfrost: gnonmefreak , lightbright , you do n...
# 88         d89  toma-: but its well worth the wait woodgrain: ...
# 89         d90  mrwes: mount shares from ubuntu server filepat...
# 90         d91  tokenekie: how do i search for commands using ...
# 91         d92  specialbuddy: well i want to know why i ca n't...
# 92         d93  nuked: ok likwidoxigen ill reboot and let you ...
# 93         d94  mohammadag: replace block with your dev node b...
# 94         d95  gopp: 01:00.0 vga compatible controller : nvid...
# 95         d96  vbabiy: yeah now i need to use something like ...
# 96         d97  noone: can some one help me with linux warpfor...
# 97         d98  earthen: it is possable that your blue tooth h...
# 98         d99  _johny: when is feisty planned to be released ...
# 99        d100  piyush: i tried sudo synaptic it says host unr...
#
#                                                  EDUs  \
# 0   edu_ID: d1e1 -> speaker: JuJuBee_ -> text: tha...
# 1   edu_ID: d2e1 -> speaker: MohammadAG -> text: r...
# 2   edu_ID: d3e1 -> speaker: sugi -> text: i guess...
# 3   edu_ID: d4e1 -> speaker: gnomefreak -> text: t...
# 4   edu_ID: d5e1 -> speaker: warbler -> text: adeb...
# 5   edu_ID: d6e1 -> speaker: niuq -> text: there i...
# 6   edu_ID: d7e1 -> speaker: nbx909 -> text: how d...
# 7   edu_ID: d8e1 -> speaker: Cmclean -> text: gefo...
# 8   edu_ID: d9e1 -> speaker: noone -> text: can so...
# 9   edu_ID: d10e1 -> speaker: rabiddachshund -> te...
# 10  edu_ID: d11e1 -> speaker: bhuey -> text: what ...
# 11  edu_ID: d12e1 -> speaker: noone -> text: can s...
# 12  edu_ID: d13e1 -> speaker: nbx909 -> text: how ...
# 13  edu_ID: d14e1 -> speaker: reD_Fox1 -> text: an...
# 14  edu_ID: d15e1 -> speaker: bhavi_bond -> text: ...
# 15  edu_ID: d16e1 -> speaker: xxiao -> text: i rec...
# 16  edu_ID: d17e1 -> speaker: warbler -> text: ade...
# 17  edu_ID: d18e1 -> speaker: vbabiy -> text: yeah...
# 18  edu_ID: d19e1 -> speaker: renegade420 -> text:...
# 19  edu_ID: d20e1 -> speaker: JuJuBee_ -> text: th...
# 20  edu_ID: d21e1 -> speaker: sugi -> text: i gues...
# 21  edu_ID: d22e1 -> speaker: rabiddachshund -> te...
# 22  edu_ID: d23e1 -> speaker: JuJuBee_ -> text: th...
# 23  edu_ID: d24e1 -> speaker: camer0ff -> text: hy...
# 24  edu_ID: d25e1 -> speaker: JuJuBee_ -> text: th...
# 25  edu_ID: d26e1 -> speaker: a111 -> text: the fl...
# 26  edu_ID: d27e1 -> speaker: cantmountanyhd -> te...
# 27  edu_ID: d28e1 -> speaker: pianoboy3333 -> text...
# 28  edu_ID: d29e1 -> speaker: dirkvdbroek -> text:...
# 29  edu_ID: d30e1 -> speaker: LjL -> text: ! backp...
# ..                                                ...
# 70  edu_ID: d71e1 -> speaker: pianoboy3333 -> text...
# 71  edu_ID: d72e1 -> speaker: EvilZx -> text: some...
# 72  edu_ID: d73e1 -> speaker: technodude -> text: ...
# 73  edu_ID: d74e1 -> speaker: Cmclean -> text: gef...
# 74  edu_ID: d75e1 -> speaker: mateusz -> text: i r...
# 75  edu_ID: d76e1 -> speaker: aliasrush -> text: y...
# 76  edu_ID: d77e1 -> speaker: matthew99857 -> text...
# 77  edu_ID: d78e1 -> speaker: lasking -> text: ple...
# 78  edu_ID: d79e1 -> speaker: MohammadAG -> text: ...
# 79  edu_ID: d80e1 -> speaker: techsupport -> text:...
# 80  edu_ID: d81e1 -> speaker: Nuked -> text: ok li...
# 81  edu_ID: d82e1 -> speaker: technodude -> text: ...
# 82  edu_ID: d83e1 -> speaker: rabiddachshund -> te...
# 83  edu_ID: d84e1 -> speaker: earthen -> text: it ...
# 84  edu_ID: d85e1 -> speaker: qkslvrwolf -> text: ...
# 85  edu_ID: d86e1 -> speaker: MohammadAG -> text: ...
# 86  edu_ID: d87e1 -> speaker: techsupport -> text:...
# 87  edu_ID: d88e1 -> speaker: timfrost -> text: gn...
# 88  edu_ID: d89e1 -> speaker: Toma- -> text: but i...
# 89  edu_ID: d90e1 -> speaker: mrwes -> text: mount...
# 90  edu_ID: d91e1 -> speaker: Tokenekie -> text: h...
# 91  edu_ID: d92e1 -> speaker: specialbuddy -> text...
# 92  edu_ID: d93e1 -> speaker: Nuked -> text: ok li...
# 93  edu_ID: d94e1 -> speaker: MohammadAG -> text: ...
# 94  edu_ID: d95e1 -> speaker: gopp -> text: 01:00....
# 95  edu_ID: d96e1 -> speaker: vbabiy -> text: yeah...
# 96  edu_ID: d97e1 -> speaker: noone -> text: can s...
# 97  edu_ID: d98e1 -> speaker: earthen -> text: it ...
# 98  edu_ID: d99e1 -> speaker: _Johny -> text: when...
# 99  edu_ID: d100e1 -> speaker: piyush -> text: i t...
#
#                                             relations  \
# 0   relation_ID: d1r1 -> type: Clarification_quest...
# 1   relation_ID: d2r1 -> type: Narration -> Arg1: ...
# 2   relation_ID: d3r1 -> type: Clarification_quest...
# 3   relation_ID: d4r1 -> type: Acknowledgement -> ...
# 4   relation_ID: d5r1 -> type: QAP -> Arg1: e1 -> ...
# 5   relation_ID: d6r1 -> type: Clarification_quest...
# 6   relation_ID: d7r1 -> type: Q-Elab -> Arg1: e1 ...
# 7   relation_ID: d8r1 -> type: Narration -> Arg1: ...
# 8   relation_ID: d9r1 -> type: Q-Elab -> Arg1: e1 ...
# 9   relation_ID: d10r1 -> type: QAP -> Arg1: e1 ->...
# 10  relation_ID: d11r1 -> type: QAP -> Arg1: e1 ->...
# 11  relation_ID: d12r1 -> type: Q-Elab -> Arg1: e1...
# 12  relation_ID: d13r1 -> type: QAP -> Arg1: e1 ->...
# 13  relation_ID: d14r1 -> type: Q-Elab -> Arg1: e1...
# 14  relation_ID: d15r1 -> type: Result -> Arg1: e1...
# 15  relation_ID: d16r1 -> type: Narration -> Arg1:...
# 16  relation_ID: d17r1 -> type: QAP -> Arg1: e1 ->...
# 17  relation_ID: d18r1 -> type: Narration -> Arg1:...
# 18  relation_ID: d19r1 -> type: Clarification_ques...
# 19  relation_ID: d20r1 -> type: Clarification_ques...
# 20  relation_ID: d21r1 -> type: Clarification_ques...
# 21  relation_ID: d22r1 -> type: QAP -> Arg1: e1 ->...
# 22  relation_ID: d23r1 -> type: Clarification_ques...
# 23  relation_ID: d24r1 -> type: QAP -> Arg1: e1 ->...
# 24  relation_ID: d25r1 -> type: Clarification_ques...
# 25  relation_ID: d26r1 -> type: QAP -> Arg1: e1 ->...
# 26  relation_ID: d27r1 -> type: Clarification_ques...
# 27  relation_ID: d28r1 -> type: QAP -> Arg1: e1 ->...
# 28  relation_ID: d29r1 -> type: Clarification_ques...
# 29  relation_ID: d30r1 -> type: Comment -> Arg1: e...
# ..                                                ...
# 70  relation_ID: d71r1 -> type: QAP -> Arg1: e1 ->...
# 71  relation_ID: d72r1 -> type: Comment -> Arg1: e...
# 72  relation_ID: d73r1 -> type: QAP -> Arg1: e1 ->...
# 73  relation_ID: d74r1 -> type: Comment -> Arg1: e...
# 74  relation_ID: d75r1 -> type: Clarification_ques...
# 75  relation_ID: d76r1 -> type: Narration -> Arg1:...
# 76  relation_ID: d77r1 -> type: Q-Elab -> Arg1: e1...
# 77  relation_ID: d78r1 -> type: QAP -> Arg1: e1 ->...
# 78  relation_ID: d79r1 -> type: Narration -> Arg1:...
# 79  relation_ID: d80r1 -> type: Comment -> Arg1: e...
# 80  relation_ID: d81r1 -> type: Clarification_ques...
# 81  relation_ID: d82r1 -> type: QAP -> Arg1: e1 ->...
# 82  relation_ID: d83r1 -> type: QAP -> Arg1: e1 ->...
# 83  relation_ID: d84r1 -> type: Background -> Arg1...
# 84  relation_ID: d85r1 -> type: QAP -> Arg1: e1 ->...
# 85  relation_ID: d86r1 -> type: Narration -> Arg1:...
# 86  relation_ID: d87r1 -> type: Comment -> Arg1: e...
# 87  relation_ID: d88r1 -> type: Clarification_ques...
# 88  relation_ID: d89r1 -> type: Clarification_ques...
# 89  relation_ID: d90r1 -> type: QAP -> Arg1: e1 ->...
# 90  relation_ID: d91r1 -> type: QAP -> Arg1: e1 ->...
# 91  relation_ID: d92r1 -> type: Clarification_ques...
# 92  relation_ID: d93r1 -> type: Clarification_ques...
# 93  relation_ID: d94r1 -> type: Narration -> Arg1:...
# 94  relation_ID: d95r1 -> type: Comment -> Arg1: e...
# 95  relation_ID: d96r1 -> type: Narration -> Arg1:...
# 96  relation_ID: d97r1 -> type: Q-Elab -> Arg1: e1...
# 97  relation_ID: d98r1 -> type: Background -> Arg1...
# 98  relation_ID: d99r1 -> type: QAP -> Arg1: e1 ->...
# 99  relation_ID: d100r1 -> type: Clarification_que...
#
#                                                   QAs
# 0   question: Where does JuJuBee_ use ? -> id: 3f4...
# 1   question: What can replace  block ? -> id: 28b...
# 2   question: What is sugi going to do ? -> id: 6c...
# 3   question: Who opened the repositories？ -> id: ...
# 4   question: What was warbler entering for the pa...
# 5   question: What does niuq want to do ? -> id: 6...
# 6   question: What does nbx909 want to do ? -> id:...
# 7   question: What does the command you gave sudo ...
# 8   question: What is everybody using here ? -> id...
# 9   question: What refers to the clicking of the w...
# 10  question: What does Flannel think ? -> id: 240...
# 11  question: What is everybody using here ? -> id...
# 12  question: What does nbx909 want to do ? -> id:...
# 13  question: Who thinks it will boot after hibern...
# 14  question: What does it show when bhavi_bond tr...
# 15  question: What does xxiao recall ? -> id: d9de...
# 16  question: What was warbler entering for the pa...
# 17  question: What is the right version？ -> id: 4e...
# 18  question: What problem does renegade420 have ?...
# 19  question: Where does JuJuBee_ use ? -> id: 978...
# 20  question: What is sugi going to do ? -> id: ef...
# 21  question: What refers to the clicking of the w...
# 22  question: Where does JuJuBee_ use ? -> id: 124...
# 23  question: What used to have dns issues with so...
# 24  question: Where does JuJuBee_ use ? -> id: c84...
# 25  question: What does CyborgSmurf want to do ? -...
# 26  question: What is that image posting site like...
# 27  question: How to hook up a monitor？ -> id: 444...
# 28  question: Who used ccooke's xorg.conf yesterda...
# 29  question: Which version does xfm want to insta...
# ..                                                ...
# 70  question: How to hook up a monitor？ -> id: d5a...
# 71  question: What does _Zeus_ suggest first？ -> i...
# 72  question: Where can build a tar file ? -> id: ...
# 73  question: What does the command you gave sudo ...
# 74  question: What did mateusz remove ? -> id: 5b8...
# 75  question: What does petr4's server have ? -> i...
# 76  question: What does ikonia use the disk ? -> i...
# 77  question: How to get instruction ? -> id: 8cca...
# 78  question: What can replace  block ? -> id: c76...
# 79  question: What does BlueEagle think about the ...
# 80  question: What does Likwidoxigen keep doing ? ...
# 81  question: Where can build a tar file ? -> id: ...
# 82  question: What refers to the clicking of the w...
# 83  question: What is just the standard hardware？ ...
# 84  question: How to get a FILEPATH manager ? -> i...
# 85  question: What can replace the block ? -> id: ...
# 86  question: Why can permission deny lol not save...
# 87  question: Who puts au on all except for securi...
# 88  question: What does woodgrain have ? -> id: 6a...
# 89  question: Where to mount shares ? -> id: d2fe6...
# 90  question: What does Tokenekie want to do ? -> ...
# 91  question: What happened to specialbuddy ? -> i...
# 92  question: What should be the address ? -> id: ...
# 93  question: What can replace block ? -> id: ec01...
# 94  question: What is for installing things ? -> i...
# 95  question: What is the right version？ -> id: 87...
# 96  question: What is everybody using here ? -> id...
# 97  question: What is just the standard hardware？ ...
# 98  question: What has Gabz read？ -> id: 01d960544...
# 99  question: Which mode is ip in ? -> id: 87ab2b8...
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Класс-наследник для создания отдельных списков (расширение метода)
#
# Генерирует отдельные списки диалогов целиком (контекстов), EDU, отношений и вопросов. При этом, где требуется, добавляется ID диалога.

# %%
class Molweni_lists(Molweni_into_pandas_QA_edition):
    list_of_contexts: list
    list_of_EDUs: list
    list_of_relations: list
    list_of_QAs: list
    
    @decor_exceptions_for_inint
    def __init__(self, input_filename: str) -> None:
        super().__init__(input_filename)
        self.list_of_contexts = self.list_maker(self.data_from_file, 'contexts')
        self.list_of_EDUs = self.list_maker(self.data_from_file, 'EDUs')
        self.list_of_relations = self.list_maker(self.data_from_file, 'relations')
        self.list_of_QAs = self.list_maker(self.data_from_file, 'QAs')
        print('You can call specific list via .list_of_contexts , .list_of_EDUs , .list_of_relations or .list_of_QAs!')
    
    def list_maker(self, data: dict, request_name: str) -> list:
        raw_dialogues = data['data']['dialogues']
        list_of_results = []
        for n in range(len(raw_dialogues)):
            (dialogue_ID, 
             context, 
             edus_of_this_dialogue, 
             relations_of_this_dialogue, 
             qas) = self.unfold(raw_dialogues[n], n+1)
            if request_name == 'contexts':
                context_item = dialogue_ID + ' >>> ' + context
                list_of_results.append(context_item)
            if request_name == 'EDUs':
                list_of_results.append(self.beauty_maker(edus_of_this_dialogue))
            if request_name == 'relations':
                list_of_results.append(self.beauty_maker(relations_of_this_dialogue))
            if request_name == 'QAs':
                qa_item = dialogue_ID + ' >>> ' + self.beauty_maker(qas)
                list_of_results.append(qa_item)
        return list_of_results

# %%
ml = Molweni_lists('test-Copy1.json')
# Out:
# Successfully unwraped! You can call in via .pandas_data
# You can call specific list via .list_of_contexts , .list_of_EDUs , .list_of_relations or .list_of_QAs!

# %%
ml.list_of_contexts[10]
# Out:
# "d11 >>> bhuey: what about via command line remotely ? bullgard4_: please read url having done so , please put here in this channel a more specific question . flannel: i do n't think that 's relevant . bullgard4_: ah ! what do you think is relevant ? flannel: url and url gives you gui and manual methods of setting static ips ( it still uses filepath bhuey: what about command line ? this is a remote machine flannel: see the second link , the serverguide one ."

# %%
print(ml.list_of_EDUs[10])
# Out:
# edu_ID: d11e1 -> speaker: bhuey -> text: what about via command line remotely ?
# edu_ID: d11e2 -> speaker: bullgard4_ -> text: please read URL having done so , please put here in this channel a more specific question .
# edu_ID: d11e3 -> speaker: Flannel -> text: i do n't think that 's relevant .
# edu_ID: d11e4 -> speaker: bullgard4_ -> text: ah ! what do you think is relevant ?
# edu_ID: d11e5 -> speaker: Flannel -> text: URL and URL gives you gui and manual methods of setting static ips ( it still uses FILEPATH
# edu_ID: d11e6 -> speaker: bhuey -> text: what about command line ? this is a remote machine
# edu_ID: d11e7 -> speaker: Flannel -> text: see the second link , the serverguide one .

# %%
print(ml.list_of_relations[10])
# Out:
# relation_ID: d11r1 -> type: QAP -> Arg1: e1 -> Arg2: e2
# relation_ID: d11r2 -> type: Comment -> Arg1: e2 -> Arg2: e3
# relation_ID: d11r3 -> type: Clarification_question -> Arg1: e3 -> Arg2: e4
# relation_ID: d11r4 -> type: QAP -> Arg1: e1 -> Arg2: e5
# relation_ID: d11r5 -> type: Clarification_question -> Arg1: e5 -> Arg2: e6
# relation_ID: d11r6 -> type: QAP -> Arg1: e6 -> Arg2: e7

# %%
print(ml.list_of_QAs[10])
# Out:
# d11 >>> question: What does Flannel think ? -> id: 240679b6ca7c02fd27189e3a9cd490f4 -> text: do n't think that 's relevant -> answer_start: 161 -> is_impossible: False
# question: What gives you gui and manual methods ? -> id: e9097168bbddefc41f0f74cbf29837f2 -> text: url and url -> answer_start: 251 -> is_impossible: False
# question: What is a remote machine ? -> id: 353fd99d1d064411354eeca68cb449a7 -> text: the serverguide one -> answer_start: 432 -> answers: [] -> is_impossible: True
# question: What does bhuey want to do ? -> id: 159640a7bff5d39960ef76b93128eaed -> text: via command line remotely -> answer_start: 18 -> is_impossible: False
# question: What is the suggestion of Flannel ? -> id: dedce5d522c476c6035e847566edf4a5 -> text: setting static ips -> answer_start: 299 -> is_impossible: False
# question: What Flannel doesn't think ? -> id: bae221c109cf878c9ad76c8b2efc2486 -> text: that 's relevant -> answer_start: 174 -> is_impossible: False
# question: What is it according to bhuey ? -> id: bcbe10d30b0f4150fbd0d8a8afecb4da -> text: a remote machine -> answer_start: 384 -> is_impossible: False
# question: Which link to see according to Flannel ? -> id: 00d9689184aaf80fdd6ed4eb2f67d794 -> text: the second link -> answer_start: 414 -> is_impossible: False
# question: What does he need to read as bullgard4_ says ? -> id: 307cff5e6b6022943471662b7dd874fd -> text: url having done so -> answer_start: 70 -> is_impossible: False
# question: What gives you gui and manual methods of setting static ips ? -> id: 4fea84915b64d452c89764590a920333 -> text: url and url -> answer_start: 251 -> is_impossible: False
# question: What is the serverguide ? -> id: 53c40229193ef28c46c96748e43789de -> text: command line -> answer_start: 22 -> answers: [] -> is_impossible: True
# question: what about via command line remotely ? -> id: b6b6c7a7e754f8da5da7c6eded89340b -> text: please read url having done so , please put here in this channel a more specific question -> answer_start: 58 -> is_impossible: False
# question: what do you think is relevant ? -> id: 43bed0c9fdd6e5170b523ad7ca4e106a -> text: url and url gives you gui and manual methods of setting static ips ( it still uses filepath -> answer_start: 251 -> is_impossible: False
# question: what about the command line ? -> id: 7401ebc2779be27918d16d9d9ade8e1b -> text: see the second link , the serverguide one  -> answer_start: 410 -> is_impossible: False
# question: what does bullgard4_ put ? -> id: 2dc126a7fc537a71cb089d31d54c9f2e -> text: a more specific question -> answer_start: 123 -> is_impossible: False
# question: what does URL give ? -> id: f7294a6d5166c84a8c5bdd83edd03f1e -> text: gui and manual methods of setting static ips -> answer_start: 273 -> is_impossible: False
# question: what does not it still use ? -> id: 899ff8ce668300d3a147d98328aab4fe -> text: the serverguide one -> answer_start: 432 -> answers: [] -> is_impossible: True
# question: What does Flannel think ? -> id: 6f8e37f8143f0f74594527df16208753 -> text: that 's relevant -> answer_start: 174 -> is_impossible: False
# question: What does the URL give ? -> id: 6cbf498100d026a7f8b7b09e7cba3644 -> text: gui and manual methods of setting static ips -> answer_start: 273 -> is_impossible: False
# question: Which link does bhuey suggest to see ? -> id: 87aac89108eb5ab019b817cc82b3dc72 -> text: the serverguide one -> answer_start: 432 -> answers: [] -> is_impossible: True
# question: What does bullgard4_ guide read ? -> id: 9b37a56df3b05c6a23a95a3caffab0ef -> text: url -> answer_start: 70 -> is_impossible: False
# question: What does bhuey want to learn ? -> id: 676d374c6d2878fe8bfe4e1a036c356e -> text: command line -> answer_start: 22 -> is_impossible: False
# question: How does Flannel feel about URL ? -> id: b6582ef210aadff5a21f5e5c63da82d3 -> text: relevant -> answer_start: 182 -> answers: [] -> is_impossible: True
# question: What does URL give to you ? -> id: 299773d134dea353099330744876578d -> text: gui and manual methods of setting static ips -> answer_start: 273 -> is_impossible: False
# question: Who disagreed bullgard4_'s opinion ? -> id: 8546d91d9c76c0f7bb168a61c04b9e7b -> text: flannel -> answer_start: 150 -> is_impossible: False
# question: Who told bhuey to read the serverguide ? -> id: 0f34b52b14685bfb9fa0c8154834fd47 -> text: flannel -> answer_start: 150 -> is_impossible: False
# question: what's bhuey's problem ? -> id: 0e7237c166d1ab68dc0d65327ed19538 -> text: via command line remotely -> answer_start: 18 -> is_impossible: False
# question: what advice does bullgard4 give ? -> id: edafb8e0819ed84cc305f981d7b09a09 -> text: read url having done so -> answer_start: 65 -> is_impossible: False
# question: who thinks it doesn't matter ? -> id: c1287b1ddb8489b580631b9ca1c12957 -> text: flannel -> answer_start: 150 -> is_impossible: False

# %% [markdown]
# ## Dataclass

# %%
@dataclass
class Molweni_data:
    raw_data: dict
    processed_data: list
    contexts: list
    EDUs: list
    relations: list
    QAs: list 

    def _init_(self: 'Molweni_data', _raw_data: dict, _processed_data: list, 
               _contexts: list, _EDUs: list, _relations: list, _QAs: list):
        self.raw_data = _raw_data
        self.processed_data = _processed_data
        self.contexts = _contexts
        self.EDUs = _EDUs
        self.relations = _relations
        self.QAs = _QAs

# %%
dtcls = Molweni_data(ml.data_from_file, ml.pandas_data, ml.list_of_contexts,
                    ml.list_of_EDUs, ml.list_of_relations, ml.list_of_QAs)

# %%
dtcls.EDUs
# Out:
# ["edu_ID: d1e1 -> speaker: JuJuBee_ -> text: that i use between linux and windows\nedu_ID: d1e2 -> speaker: nit-wit -> text: did you mount it with fstab ? give us a pastebin of the fstab that is probably it eh.EMOJI\nedu_ID: d1e3 -> speaker: ikonia -> text: it 's treated as a mount mask\nedu_ID: d1e4 -> speaker: zykotick9 -> text: umask are subtracted , so your other group has no permission\nedu_ID: d1e5 -> speaker: ikonia -> text: what ever permissions you feel fit\nedu_ID: d1e6 -> speaker: MrNthDegree -> text: outdated by loads , it has 9.04 as the newest version\nedu_ID: d1e7 -> speaker: SuperMiguel -> text: they are back in 9.04 : s",
#  "edu_ID: d2e1 -> speaker: MohammadAG -> text: replace block with your dev node\nedu_ID: d2e2 -> speaker: blue_pearl -> text: here is the output when i ran the comman\nedu_ID: d2e3 -> speaker: blue_pearl -> text: URL here is the output\nedu_ID: d2e4 -> speaker: MohammadAG -> text: i 'm assuming it 's not raid ?\nedu_ID: d2e5 -> speaker: blue_pearl -> text: well first it did not mounted after i did not properly shutdown xp and booted in ubuntu\nedu_ID: d2e6 -> speaker: blue_pearl -> text: i can try but how to run it ?\nedu_ID: d2e7 -> speaker: MohammadAG -> text: i 'm not sure about xp , but vista and 7 had a recovery disc option\nedu_ID: d2e8 -> speaker: blue_pearl -> text: ok. will reinstalling the grub2 help in any way ?",
#  "edu_ID: d3e1 -> speaker: sugi -> text: i guess there is not enough gamers here to share my woos\nedu_ID: d3e2 -> speaker: Sa[i]nT -> text: plenty of gamers , just not witcher fans ?\nedu_ID: d3e3 -> speaker: vocx -> text: go to ubuntu-offtopic or ubuntu-cafe or ubuntuforums , plenty of offtopic discussion channels\nedu_ID: d3e4 -> speaker: sugi -> text: i am not a fan yet . i have n't tried it EMOJI\nedu_ID: d3e5 -> speaker: Sa[i]nT -> text: i 've heard more bad than good . but ya never know .\nedu_ID: d3e6 -> speaker: sugi -> text: i just keep hearing about it\nedu_ID: d3e7 -> speaker: Sa[i]nT -> text: wan na try something interesting , try spore\nedu_ID: d3e8 -> speaker: sugi -> text: already installed it and beaten it EMOJI",
#  "edu_ID: d4e1 -> speaker: gnomefreak -> text: to me it looks like its trying to read the cdrom for universe\nedu_ID: d4e2 -> speaker: lightbright -> text: ok synaptic is open ! and i opened the repositories\nedu_ID: d4e3 -> speaker: gnomefreak -> text: what is the first thing you see\nedu_ID: d4e4 -> speaker: gnomefreak -> text: is there a check near it ?\nedu_ID: d4e5 -> speaker: theine -> text: since when are you getting these errors ?\nedu_ID: d4e6 -> speaker: lightbright -> text: a check ? as in tick ?\nedu_ID: d4e7 -> speaker: lightbright -> text: after 5months using ubuntu my first day ever getting these errors\nedu_ID: d4e8 -> speaker: lightbright -> text: there is no tick on any of the 12 that appear\nedu_ID: d4e9 -> speaker: lightbright -> text: i dont see any boxes !\nedu_ID: d4e10 -> speaker: theine -> text: hmm , ok , try `` apt-get update '' again\nedu_ID: d4e11 -> speaker: gnomefreak -> text: than click show all or something like that",
#  "edu_ID: d5e1 -> speaker: warbler -> text: adebo : what are you entering for the partition ?\nedu_ID: d5e2 -> speaker: abedo -> text: the setup does n't work , it gave me no such partition\nedu_ID: d5e3 -> speaker: warbler -> text: what were you entering for the partition ?\nedu_ID: d5e4 -> speaker: abedo -> text: root ( hd0,5 ) - setup ( hd0,5 )\nedu_ID: d5e5 -> speaker: warbler -> text: root ( hd0.5 ) - setup ( hd0 )\nedu_ID: d5e6 -> speaker: abedo -> text: i tried it dude it 's same\nedu_ID: d5e7 -> speaker: warbler -> text: if it finds grub it will install grub - one step at a time - ok ?\nedu_ID: d5e8 -> speaker: warbler -> text: from live cd - at terminal - type sudo grub - ok ?\nedu_ID: d5e9 -> speaker: abedo -> text: i 'm testing again , hope EMOJI\nedu_ID: d5e10 -> speaker: warbler -> text: with result from find type - root ( hd0,5 ) - if that is what it finds\nedu_ID: d5e11 -> speaker: warbler -> text: then type - root ( hd0 ) - hit enter - should be output - ok ?",
#  "edu_ID: d6e1 -> speaker: niuq -> text: there is any way to disable tapping from my touchpad it 's really annoying\nedu_ID: d6e2 -> speaker: DjViper -> text: you could disable it alltogether ?\nedu_ID: d6e3 -> speaker: foso -> text: that line is already there\nedu_ID: d6e4 -> speaker: DjViper -> text: okay , do the next step then\nedu_ID: d6e5 -> speaker: niuq -> text: yes i do , i dont even have a mouse\nedu_ID: d6e6 -> speaker: foso -> text: when i control x and then say yes then enter it says error writing permission dnied\nedu_ID: d6e7 -> speaker: DjViper -> text: you need to do it as root , read up",
#  "edu_ID: d7e1 -> speaker: nbx909 -> text: how do i find the address of a usb device ?\nedu_ID: d7e2 -> speaker: Likwidoxigen -> text: what sort of device ?\nedu_ID: d7e3 -> speaker: babo -> text: ca n't i just copy over the os and leave the data files untouched ?\nedu_ID: d7e4 -> speaker: nbx909 -> text: only if you do an upgrade\nedu_ID: d7e5 -> speaker: babo -> text: how do i do an upgrade then ?\nedu_ID: d7e6 -> speaker: Nuked -> text: should i just restart x after installing\nedu_ID: d7e7 -> speaker: Likwidoxigen -> text: i 'd do a full restart so that it re-loads the modules",
#  "edu_ID: d8e1 -> speaker: Cmclean -> text: geforce4 mx 440 with agp8x ( gpu 0\nedu_ID: d8e2 -> speaker: deagle -> text: you wo n't see any changes ( obviously ) until you restart\nedu_ID: d8e3 -> speaker: deagle -> text: just hit ctrl.altbackspace ( save and close out stuff before you do so )\nedu_ID: d8e4 -> speaker: Cmclean -> text: umm there is no default res thingy when i do that .\nedu_ID: d8e5 -> speaker: deagle -> text: who in the what now : ?\nedu_ID: d8e6 -> speaker: Cmclean -> text: the command you gave sudo get some file conf.x\nedu_ID: d8e7 -> speaker: deagle -> text: goto where it says section `` screen ''\nedu_ID: d8e8 -> speaker: deagle -> text: subsection `` display '' then modes `` 1280x1024 '' `` 1600x1200 '' etc\nedu_ID: d8e9 -> speaker: Cmclean -> text: thas the whole thing ctrla paste\nedu_ID: d8e10 -> speaker: deagle -> text: FILEPATH that into the xorg.conf file overwrite your section `` screen '' with that one",
#  "edu_ID: d9e1 -> speaker: noone -> text: can some one help me with linux\nedu_ID: d9e2 -> speaker: warpforge -> text: what do you want to do ?\nedu_ID: d9e3 -> speaker: _jason -> text: you 're going to have to be more specific . just state your problem .\nedu_ID: d9e4 -> speaker: tech9iner -> text: hello ? .. ahem.. you are in ubuntu..\nedu_ID: d9e5 -> speaker: trappist -> text: please please just skip ahead to your question\nedu_ID: d9e6 -> speaker: ubotu -> text: did you get hit by a windmill ? i do n't know , could you explain it ?\nedu_ID: d9e7 -> speaker: _jason -> text: tell tech9iner about msg the bot\nedu_ID: d9e8 -> speaker: guillem101 -> text: how do i check ubotu messg ?\nedu_ID: d9e9 -> speaker: _jason -> text: what client are you using for irc ?",
#  "edu_ID: d10e1 -> speaker: rabiddachshund -> text: `` button 3 '' refers to the mouse scroll wheel , right ?\nedu_ID: d10e2 -> speaker: fyrestrtr -> text: yes , the clicking of the wheel , not scrolling ( that 's 4 and 5 , iirc )\nedu_ID: d10e3 -> speaker: alexbOrsova -> text: rebooting gets it back for a few more minutes\nedu_ID: d10e4 -> speaker: Kworth -> text: now how can i implement the usb card if it has an own entry ?\nedu_ID: d10e5 -> speaker: alexbOrsova -> text: also , internet works just fine from same machine from windows\nedu_ID: d10e6 -> speaker: fyrestrtr -> text: you might need some magic to make it work EMOJI\nedu_ID: d10e7 -> speaker: Kworth -> text: dont be silly , isnt there a way ?\nedu_ID: d10e8 -> speaker: fyrestrtr -> text: no clue .. its a strange one . can you pastebin some logs ?\nedu_ID: d10e9 -> speaker: alexbOrsova -> text: pastebin ? will you be here in a few minutes ?\nedu_ID: d10e10 -> speaker: alexbOrsova -> text: i need to reboot , brb\nedu_ID: d10e11 -> speaker: fyrestrtr -> text: grep eth0 FILEPATH and also dmesg grep eth",
#  "edu_ID: d11e1 -> speaker: bhuey -> text: what about via command line remotely ?\nedu_ID: d11e2 -> speaker: bullgard4_ -> text: please read URL having done so , please put here in this channel a more specific question .\nedu_ID: d11e3 -> speaker: Flannel -> text: i do n't think that 's relevant .\nedu_ID: d11e4 -> speaker: bullgard4_ -> text: ah ! what do you think is relevant ?\nedu_ID: d11e5 -> speaker: Flannel -> text: URL and URL gives you gui and manual methods of setting static ips ( it still uses FILEPATH\nedu_ID: d11e6 -> speaker: bhuey -> text: what about command line ? this is a remote machine\nedu_ID: d11e7 -> speaker: Flannel -> text: see the second link , the serverguide one .",
#  "edu_ID: d12e1 -> speaker: noone -> text: can some one help me with linux\nedu_ID: d12e2 -> speaker: warpforge -> text: what do you want to do ?\nedu_ID: d12e3 -> speaker: _jason -> text: you 're going to have to be more specific . just state your problem .\nedu_ID: d12e4 -> speaker: Ng -> text: everybody here is using ubuntu , just ask your question\nedu_ID: d12e5 -> speaker: tech9iner -> text: hello ? .. ahem.. you are in ubuntu..\nedu_ID: d12e6 -> speaker: trappist -> text: please please just skip ahead to your question\nedu_ID: d12e7 -> speaker: ubotu -> text: did you get hit by a windmill ? i do n't know , could you explain it ?\nedu_ID: d12e8 -> speaker: _jason -> text: tell tech9iner about msg the bot\nedu_ID: d12e9 -> speaker: guillem101 -> text: how do i check ubotu messg ?",
#  "edu_ID: d13e1 -> speaker: nbx909 -> text: how do i find the address of a usb device ?\nedu_ID: d13e2 -> speaker: Likwidoxigen -> text: try taking it out to dinner and do a little wine and dine and it shoudl tell ya\nedu_ID: d13e3 -> speaker: Likwidoxigen -> text: what sort of device ?\nedu_ID: d13e4 -> speaker: babo -> text: ca n't i just copy over the os and leave the data files untouched ?\nedu_ID: d13e5 -> speaker: nbx909 -> text: only if you do an upgrade\nedu_ID: d13e6 -> speaker: babo -> text: how do i do an upgrade then ?\nedu_ID: d13e7 -> speaker: Nuked -> text: should i just restart x after installing",
#  "edu_ID: d14e1 -> speaker: reD_Fox1 -> text: anyone have any idea why ubuntu would boot correctly after hanging during one boot , and visa versa ?\nedu_ID: d14e2 -> speaker: kazim59 -> text: when it hangs , what does it say before hanging itself ?\nedu_ID: d14e3 -> speaker: reD_Fox1 -> text: in fact , i think it will boot after hibernating\nedu_ID: d14e4 -> speaker: reD_Fox1 -> text: it hangs on a blank ( `` dead '' ) screen\nedu_ID: d14e5 -> speaker: reD_Fox1 -> text: it appears to be just as gnome is loading\nedu_ID: d14e6 -> speaker: kazim59 -> text: can you get a login prompt by pressing ctrlaltf1 when it hangs ?\nedu_ID: d14e7 -> speaker: reD_Fox1 -> text: no , and ctrl-alt-del will not reboot , either\nedu_ID: d14e8 -> speaker: Roham -> text: nothing happens it still says network:0 disabled when i push the button\nedu_ID: d14e9 -> speaker: reD_Fox1 -> text: when i reboot the computer manually to recover from the hang , it boots fine\nedu_ID: d14e10 -> speaker: kazim59 -> text: can you copy FILEPATH to a pastie ?\nedu_ID: d14e11 -> speaker: kazim59 -> text: seems that it hangs after a proper shutdown right ?\nedu_ID: d14e12 -> speaker: myusrnm -> text: rm : can not remove FILEPATH read-only file system\nedu_ID: d14e13 -> speaker: kazim59 -> text: can you give me contents of FILEPATH",
#  "edu_ID: d15e1 -> speaker: bhavi_bond -> text: channel [ linuxmobile ] does not exist error when i try to register\nedu_ID: d15e2 -> speaker: Answer -> text: that channel does not exist . try another channel .\nedu_ID: d15e3 -> speaker: crane_ -> text: so have you joined that channel ?\nedu_ID: d15e4 -> speaker: crane_ -> text: and you are trying to register it ?\nedu_ID: d15e5 -> speaker: crane_ -> text: i do n't think this is an ubuntu problem .\nedu_ID: d15e6 -> speaker: kingcobra -> text: yes but i would like a page explaining umask options\nedu_ID: d15e7 -> speaker: numan -> text: can you tell me how to get the media codecs for totem mplayer",
#  'edu_ID: d16e1 -> speaker: xxiao -> text: i recall there is erlang java version etc\nedu_ID: d16e2 -> speaker: elnomade -> text: there is a xmpp servers comparison chart\nedu_ID: d16e3 -> speaker: xxiao -> text: cool , is that for faculty or just students , or the whole univ ?\nedu_ID: d16e4 -> speaker: elnomade -> text: based on that , i choose openfire\nedu_ID: d16e5 -> speaker: elnomade -> text: i enable gateways to msn , yahoo and gtalk\nedu_ID: d16e6 -> speaker: xxiao -> text: those are java plugins i assume ?\nedu_ID: d16e7 -> speaker: elnomade -> text: open-source xmpp server comparison chart',
#  "edu_ID: d17e1 -> speaker: warbler -> text: adebo : what are you entering for the partition ?\nedu_ID: d17e2 -> speaker: abedo -> text: the setup does n't work , it gave me no such partition\nedu_ID: d17e3 -> speaker: warbler -> text: what were you entering for the partition ?\nedu_ID: d17e4 -> speaker: abedo -> text: root ( hd0,5 ) - setup ( hd0,5 )\nedu_ID: d17e5 -> speaker: warbler -> text: it is - setup ( hd0 ) - to get grub on the start of the first disk\nedu_ID: d17e6 -> speaker: warbler -> text: root ( hd0.5 ) - setup ( hd0 )\nedu_ID: d17e7 -> speaker: abedo -> text: i tried it dude it 's same\nedu_ID: d17e8 -> speaker: warbler -> text: if it finds grub it will install grub - one step at a time - ok ?\nedu_ID: d17e9 -> speaker: warbler -> text: from live cd - at terminal - type sudo grub - ok ?\nedu_ID: d17e10 -> speaker: abedo -> text: i 'm testing again , hope EMOJI\nedu_ID: d17e11 -> speaker: warbler -> text: then type - root ( hd0 ) - hit enter - should be output - ok ?",
#  "edu_ID: d18e1 -> speaker: vbabiy -> text: yeah now i need to use something like awk to feed it in to vim\nedu_ID: d18e2 -> speaker: kthef -> text: grep asdf .FILEPATH -l test.3 cat test.3 xargs vim\nedu_ID: d18e3 -> speaker: kthef -> text: you may have to tweak it a little\nedu_ID: d18e4 -> speaker: kthef -> text: make sure you have the right version of the router before you attemptmine is an old version 2\nedu_ID: d18e5 -> speaker: kthef -> text: not you , sorry , should be for killerorca\nedu_ID: d18e6 -> speaker: KillerOrca -> text: have it running , just ca n't ssh to box using it as wireless adaptor\nedu_ID: d18e7 -> speaker: kthef -> text: you set it up as a wireless bridge ?",
#  "edu_ID: d19e1 -> speaker: renegade420 -> text: i am having a problem with users not being able to write to a removable drive\nedu_ID: d19e2 -> speaker: BlueEagle -> text: which file system is on the drive ?\nedu_ID: d19e3 -> speaker: techsupport -> text: used nano , not sure how to check if it made a backup no such file or directory\nedu_ID: d19e4 -> speaker: BlueEagle -> text: then it did n't create a backup .\nedu_ID: d19e5 -> speaker: techsupport -> text: can you pastebin your FILEPATH for me , if its in it 's original form\nedu_ID: d19e6 -> speaker: renegade420 -> text: its not that ii ca n't mount it . i just ca n't write to it .\nedu_ID: d19e7 -> speaker: BlueEagle -> text: did you try : dpkg -- configure pam\nedu_ID: d19e8 -> speaker: bobertdos -> text: is there an entry in fstab for it or have you mounted it manually ?\nedu_ID: d19e9 -> speaker: bobertdos -> text: it 's probable that it did n't get mounted with write permissions .",
#  "edu_ID: d20e1 -> speaker: JuJuBee_ -> text: that i use between linux and windows\nedu_ID: d20e2 -> speaker: nit-wit -> text: did you mount it with fstab ? give us a pastebin of the fstab that is probably it eh.EMOJI\nedu_ID: d20e3 -> speaker: ikonia -> text: it 's treated as a mount mask\nedu_ID: d20e4 -> speaker: ikonia -> text: what ever permissions you feel fit\nedu_ID: d20e5 -> speaker: nit-wit -> text: this is the line FILEPATH FILEPATH ntfs-3g quiet , defaults , locale=en_us.utf8 , umask=0\nedu_ID: d20e6 -> speaker: MrNthDegree -> text: outdated by loads , it has 9.04 as the newest version\nedu_ID: d20e7 -> speaker: SuperMiguel -> text: they are back in 9.04 : s",
#  "edu_ID: d21e1 -> speaker: sugi -> text: i guess there is not enough gamers here to share my woos\nedu_ID: d21e2 -> speaker: Sa[i]nT -> text: plenty of gamers , just not witcher fans ?\nedu_ID: d21e3 -> speaker: vocx -> text: go to ubuntu-offtopic or ubuntu-cafe or ubuntuforums , plenty of offtopic discussion channels\nedu_ID: d21e4 -> speaker: sugi -> text: i am not a fan yet . i have n't tried it EMOJI\nedu_ID: d21e5 -> speaker: Sa[i]nT -> text: i 've heard more bad than good . but ya never know .\nedu_ID: d21e6 -> speaker: sugi -> text: i just keep hearing about it\nedu_ID: d21e7 -> speaker: Sa[i]nT -> text: wan na try something interesting , try spore\nedu_ID: d21e8 -> speaker: sugi -> text: great game though . even though everyone keeps shooting it down . it makes me a bit mad",
#  "edu_ID: d22e1 -> speaker: rabiddachshund -> text: `` button 3 '' refers to the mouse scroll wheel , right ?\nedu_ID: d22e2 -> speaker: fyrestrtr -> text: yes , the clicking of the wheel , not scrolling ( that 's 4 and 5 , iirc )\nedu_ID: d22e3 -> speaker: alexbOrsova -> text: rebooting gets it back for a few more minutes\nedu_ID: d22e4 -> speaker: Kworth -> text: i have found it : magic control technology corp\nedu_ID: d22e5 -> speaker: Kworth -> text: now how can i implement the usb card if it has an own entry ?\nedu_ID: d22e6 -> speaker: alexbOrsova -> text: also , internet works just fine from same machine from windows\nedu_ID: d22e7 -> speaker: fyrestrtr -> text: you might need some magic to make it work EMOJI\nedu_ID: d22e8 -> speaker: fyrestrtr -> text: no clue .. its a strange one . can you pastebin some logs ?\nedu_ID: d22e9 -> speaker: alexbOrsova -> text: pastebin ? will you be here in a few minutes ?\nedu_ID: d22e10 -> speaker: alexbOrsova -> text: i need to reboot , brb\nedu_ID: d22e11 -> speaker: fyrestrtr -> text: grep eth0 FILEPATH and also dmesg grep eth",
#  "edu_ID: d23e1 -> speaker: JuJuBee_ -> text: that i use between linux and windows\nedu_ID: d23e2 -> speaker: nit-wit -> text: did you mount it with fstab ? give us a pastebin of the fstab that is probably it eh.EMOJI\nedu_ID: d23e3 -> speaker: ikonia -> text: it 's treated as a mount mask\nedu_ID: d23e4 -> speaker: zykotick9 -> text: umask are subtracted , so your other group has no permission\nedu_ID: d23e5 -> speaker: ikonia -> text: what ever permissions you feel fit\nedu_ID: d23e6 -> speaker: nit-wit -> text: this is the line FILEPATH FILEPATH ntfs-3g quiet , defaults , locale=en_us.utf8 , umask=0\nedu_ID: d23e7 -> speaker: MrNthDegree -> text: outdated by loads , it has 9.04 as the newest version",
#  "edu_ID: d24e1 -> speaker: camer0ff -> text: hyper_ch thats pretty much it.. i can send you the entire lot of info if you like ?\nedu_ID: d24e2 -> speaker: Linux_Galore -> text: i remember 5.10 used to have dns issues with some routers , 6.06 fixed it all\nedu_ID: d24e3 -> speaker: camer0ff -> text: cool well we will see with the xubuntu 6.10 version EMOJI\nedu_ID: d24e4 -> speaker: hyper_ch -> text: please pastebin the content of your FILEPATH and FILEPATH file\nedu_ID: d24e5 -> speaker: Linux_Galore -> text: 5.10 was very much an experimental release , lots of breakage\nedu_ID: d24e6 -> speaker: gnomefreak -> text: no its not breezy was very stable\nedu_ID: d24e7 -> speaker: Linux_Galore -> text: most of the issues i had with 6,10 were because of a poor update manager setup\nedu_ID: d24e8 -> speaker: gnomefreak -> text: edgy was the `` experimental '' in some peoples eyes",
#  "edu_ID: d25e1 -> speaker: JuJuBee_ -> text: that i use between linux and windows\nedu_ID: d25e2 -> speaker: nit-wit -> text: did you mount it with fstab ? give us a pastebin of the fstab that is probably it eh.EMOJI\nedu_ID: d25e3 -> speaker: ikonia -> text: it 's treated as a mount mask\nedu_ID: d25e4 -> speaker: zykotick9 -> text: umask are subtracted , so your other group has no permission\nedu_ID: d25e5 -> speaker: ikonia -> text: what ever permissions you feel fit\nedu_ID: d25e6 -> speaker: nit-wit -> text: this is the line FILEPATH FILEPATH ntfs-3g quiet , defaults , locale=en_us.utf8 , umask=0\nedu_ID: d25e7 -> speaker: SuperMiguel -> text: they are back in 9.04 : s",
#  "edu_ID: d26e1 -> speaker: a111 -> text: the flash player for your browser cy ?\nedu_ID: d26e2 -> speaker: CyborgSmurf -> text: i mean where to create flash stuff\nedu_ID: d26e3 -> speaker: Myrtti -> text: no gui apps , flex is your best bet\nedu_ID: d26e4 -> speaker: sirfilipwork -> text: there was a flexbuilder for linux not sure if its live any more\nedu_ID: d26e5 -> speaker: CyborgSmurf -> text: if i dont use it in a gui , is it straightly command line ?\nedu_ID: d26e6 -> speaker: CyborgSmurf -> text: okay , i will check it out\nedu_ID: d26e7 -> speaker: Myrtti -> text: not commandline , but 'coding ' with text editor",
#  "edu_ID: d27e1 -> speaker: cantmountanyhd -> text: what is that image posting site like pastebin ? let me upload the screenshot\nedu_ID: d27e2 -> speaker: codebrainz -> text: ca n't just paste the text ?\nedu_ID: d27e3 -> speaker: codebrainz -> text: this comes up in google : URL\nedu_ID: d27e4 -> speaker: codebrainz -> text: easiest solution is to boot back into windows and shutdown properly\nedu_ID: d27e5 -> speaker: cantmountanyhd -> text: but i have done it so many times\nedu_ID: d27e6 -> speaker: cantmountanyhd -> text: then i have done it more than a few times\nedu_ID: d27e7 -> speaker: codebrainz -> text: you can mount with the -- force option , by doing it manually",
#  "edu_ID: d28e1 -> speaker: pianoboy3333 -> text: does anyone know how to hook up a monitor with a dvi digital cable in ubuntu\nedu_ID: d28e2 -> speaker: trappist -> text: you plug it into the dvi connector on your video card\nedu_ID: d28e3 -> speaker: sethk -> text: it is no different than hooking up a monitor with a vga cable\nedu_ID: d28e4 -> speaker: pianoboy3333 -> text: i had to switch to vga for installing ubuntu tho\nedu_ID: d28e5 -> speaker: jayr -> text: it an nvidia base card\nedu_ID: d28e6 -> speaker: soundray -> text: have you found FILEPATH yet ? there are readmes in there .\nedu_ID: d28e7 -> speaker: Stork -> text: how do i use the script ? i ca n't figure it out :",
#  "edu_ID: d29e1 -> speaker: dirkvdbroek -> text: i know my bit around the system , but i do n't know how to diagnose this .\nedu_ID: d29e2 -> speaker: ccooke -> text: what 's the exact problem you 're getting ?\nedu_ID: d29e3 -> speaker: dirkvdbroek -> text: i used your xorg.conf yesterday\nedu_ID: d29e4 -> speaker: ccooke -> text: can you post your FILEPATH you know where the pastebin is , right ?\nedu_ID: d29e5 -> speaker: dirkvdbroek -> text: could you give me the adress again ? EMOJI\nedu_ID: d29e6 -> speaker: ccooke -> text: if i recall correclty , it looked like it may be agp problems , right ?\nedu_ID: d29e7 -> speaker: ccooke -> text: you could try blacklisting the agp modules",
#  "edu_ID: d30e1 -> speaker: LjL -> text: ! backports xfm ( xfm , see the private message from ubotu )\nedu_ID: d30e2 -> speaker: xfm -> text: mmm the current version bugs on my computer i would like to try the last one\nedu_ID: d30e3 -> speaker: LjL -> text: what version are you using ? ( apt-cache policy pidgin )\nedu_ID: d30e4 -> speaker: unop -> text: it tries to recreate FILEPATH if they do n't exist\nedu_ID: d30e5 -> speaker: LjL -> text: how does it do that though ? by guessing like the script they propose ?\nedu_ID: d30e6 -> speaker: unop -> text: yea - not sure of the workings\nedu_ID: d30e7 -> speaker: xfm -> text: i have removed version 2.4.1 , i want to install 2.5.1\nedu_ID: d30e8 -> speaker: LjL -> text: 2.5.1 is available from backports . get it from there , please .\nedu_ID: d30e9 -> speaker: ferretonthelus -> text: the page does n't exist that the url links to .\nedu_ID: d30e10 -> speaker: unop -> text: ok , wait , does this command give you anything ? ls FILEPATH\nedu_ID: d30e11 -> speaker: unop -> text: you forgot the i put on the end",
#  "edu_ID: d31e1 -> speaker: warbler -> text: adebo : what are you entering for the partition ?\nedu_ID: d31e2 -> speaker: abedo -> text: the setup does n't work , it gave me no such partition\nedu_ID: d31e3 -> speaker: warbler -> text: what were you entering for the partition ?\nedu_ID: d31e4 -> speaker: abedo -> text: root ( hd0,5 ) - setup ( hd0,5 )\nedu_ID: d31e5 -> speaker: warbler -> text: it is - setup ( hd0 ) - to get grub on the start of the first disk\nedu_ID: d31e6 -> speaker: warbler -> text: root ( hd0.5 ) - setup ( hd0 )\nedu_ID: d31e7 -> speaker: abedo -> text: i tried it dude it 's same\nedu_ID: d31e8 -> speaker: warbler -> text: from live cd - at terminal - type sudo grub - ok ?\nedu_ID: d31e9 -> speaker: abedo -> text: i 'm testing again , hope EMOJI\nedu_ID: d31e10 -> speaker: warbler -> text: with result from find type - root ( hd0,5 ) - if that is what it finds\nedu_ID: d31e11 -> speaker: warbler -> text: then type - root ( hd0 ) - hit enter - should be output - ok ?",
#  "edu_ID: d32e1 -> speaker: sugi -> text: i guess there is not enough gamers here to share my woos\nedu_ID: d32e2 -> speaker: Sa[i]nT -> text: plenty of gamers , just not witcher fans ?\nedu_ID: d32e3 -> speaker: sugi -> text: i am not a fan yet . i have n't tried it EMOJI\nedu_ID: d32e4 -> speaker: Sa[i]nT -> text: i 've heard more bad than good . but ya never know .\nedu_ID: d32e5 -> speaker: sugi -> text: i just keep hearing about it\nedu_ID: d32e6 -> speaker: Sa[i]nT -> text: wan na try something interesting , try spore\nedu_ID: d32e7 -> speaker: sugi -> text: already installed it and beaten it EMOJI\nedu_ID: d32e8 -> speaker: sugi -> text: great game though . even though everyone keeps shooting it down . it makes me a bit mad",
#  "edu_ID: d33e1 -> speaker: vbabiy -> text: yeah now i need to use something like awk to feed it in to vim\nedu_ID: d33e2 -> speaker: kthef -> text: grep pattern files -l list_of_files cat list_of_files xargs vim try that\nedu_ID: d33e3 -> speaker: kthef -> text: grep asdf .FILEPATH -l test.3 cat test.3 xargs vim\nedu_ID: d33e4 -> speaker: kthef -> text: make sure you have the right version of the router before you attemptmine is an old version 2\nedu_ID: d33e5 -> speaker: kthef -> text: not you , sorry , should be for killerorca\nedu_ID: d33e6 -> speaker: KillerOrca -> text: have it running , just ca n't ssh to box using it as wireless adaptor\nedu_ID: d33e7 -> speaker: kthef -> text: you set it up as a wireless bridge ?",
#  'edu_ID: d34e1 -> speaker: rhodry_2409 -> text: and i have input output errors\nedu_ID: d34e2 -> speaker: comicinker -> text: you can use autocomplete for usernames , punshing in the first letters and hit tab\nedu_ID: d34e3 -> speaker: comicinker -> text: what filesystem are you using on your sd , did you empty the trash ?\nedu_ID: d34e4 -> speaker: rhodry_2409 -> text: my system is in french , i will try to translate\nedu_ID: d34e5 -> speaker: rhodry_2409 -> text: error when open the file : input and output erreor\nedu_ID: d34e6 -> speaker: comicinker -> text: ah , vous parlez en francaise , mais , je ne parlez pas EMOJI . what filesystem ?\nedu_ID: d34e7 -> speaker: rhodry_2409 -> text: yes , i have format the card just before trying tor write on it\nedu_ID: d34e8 -> speaker: comicinker -> text: did you try fsck on it ?',
#  "edu_ID: d35e1 -> speaker: cantmountanyhd -> text: what is that image posting site like pastebin ? let me upload the screenshot\nedu_ID: d35e2 -> speaker: codebrainz -> text: ca n't just paste the text ?\nedu_ID: d35e3 -> speaker: codebrainz -> text: this comes up in google : URL\nedu_ID: d35e4 -> speaker: codebrainz -> text: easiest solution is to boot back into windows and shutdown properly\nedu_ID: d35e5 -> speaker: cantmountanyhd -> text: but i have done it so many times\nedu_ID: d35e6 -> speaker: cantmountanyhd -> text: restart through windows is a proper shut down right ?\nedu_ID: d35e7 -> speaker: cantmountanyhd -> text: then i have done it more than a few times",
#  'edu_ID: d36e1 -> speaker: starscalling -> text: but if you do df -h can u see where its mounted ?\nedu_ID: d36e2 -> speaker: Toma- -> text: ls FILEPATH will tell you the user installed\nedu_ID: d36e3 -> speaker: starscalling -> text: i cant figure how to get into it to see whats up\nedu_ID: d36e4 -> speaker: Plazma -> text: its not even detecting itas a drive\nedu_ID: d36e5 -> speaker: starscalling -> text: do you have any other firewire devices ?\nedu_ID: d36e6 -> speaker: Toma- -> text: i see . you wan na get into the machine without login ?\nedu_ID: d36e7 -> speaker: starscalling -> text: perhaps the problem lies in the firewier thing',
#  'edu_ID: d37e1 -> speaker: starscalling -> text: but if you do df -h can u see where its mounted ?\nedu_ID: d37e2 -> speaker: Toma- -> text: ls FILEPATH will tell you the user installed\nedu_ID: d37e3 -> speaker: starscalling -> text: i cant figure how to get into it to see whats up\nedu_ID: d37e4 -> speaker: Plazma -> text: its not even detecting itas a drive\nedu_ID: d37e5 -> speaker: starscalling -> text: do you have any other firewire devices ?\nedu_ID: d37e6 -> speaker: starscalling -> text: perhaps the problem lies in the firewier thing\nedu_ID: d37e7 -> speaker: Plazma -> text: well the card itslef works in winblows and so doest he ipod so',
#  "edu_ID: d38e1 -> speaker: technodude -> text: can you build a tar file on a debian based distro ?\nedu_ID: d38e2 -> speaker: cafuego -> text: of course . just make sure you use .FILEPATH -- prefix=FILEPATH\nedu_ID: d38e3 -> speaker: predaeus -> text: t 's a alcatel usb speedtouch\nedu_ID: d38e4 -> speaker: cafuego -> text: probably a badly ported driver , then .\nedu_ID: d38e5 -> speaker: cafuego -> text: can you swap it over for an ethernet one ?\nedu_ID: d38e6 -> speaker: predaeus -> text: then it would n't run under the x86 live cd also i think .\nedu_ID: d38e7 -> speaker: predaeus -> text: no should and must work with usb\nedu_ID: d38e8 -> speaker: cafuego -> text: no , alcatel have provided a driver which does n't work under 64bit kernels , it seems .",
#  "edu_ID: d39e1 -> speaker: nbx909 -> text: how do i find the address of a usb device ?\nedu_ID: d39e2 -> speaker: Likwidoxigen -> text: try taking it out to dinner and do a little wine and dine and it shoudl tell ya\nedu_ID: d39e3 -> speaker: Likwidoxigen -> text: what sort of device ?\nedu_ID: d39e4 -> speaker: babo -> text: ca n't i just copy over the os and leave the data files untouched ?\nedu_ID: d39e5 -> speaker: nbx909 -> text: only if you do an upgrade\nedu_ID: d39e6 -> speaker: Nuked -> text: should i just restart x after installing\nedu_ID: d39e7 -> speaker: Likwidoxigen -> text: i 'd do a full restart so that it re-loads the modules",
#  "edu_ID: d40e1 -> speaker: techsupport -> text: bluedusk , no , but i dont want to change anything else just that file\nedu_ID: d40e2 -> speaker: BlueEagle -> text: those are the two non-comented lines in it .\nedu_ID: d40e3 -> speaker: BlueEagle -> text: the inverted i-s are tabs me thinks\nedu_ID: d40e4 -> speaker: BlueEagle -> text: you 'll need to be more spesific .\nedu_ID: d40e5 -> speaker: techsupport -> text: i just need the original contents of FILEPATH , can you provide me with that please sir ?\nedu_ID: d40e6 -> speaker: BlueEagle -> text: i already pasted the two non-commented lines in that file .\nedu_ID: d40e7 -> speaker: techsupport -> text: permission denied lol cant save the file\nedu_ID: d40e8 -> speaker: BlueEagle -> text: that 's because it 's owned by root .\nedu_ID: d40e9 -> speaker: techsupport -> text: with the user that i 'm looged in as\nedu_ID: d40e10 -> speaker: BlueEagle -> text: but you already know that , do n't you ?\nedu_ID: d40e11 -> speaker: techsupport -> text: so how can i login as sudo user now",
#  'edu_ID: d41e1 -> speaker: rhodry_2409 -> text: and i have input output errors\nedu_ID: d41e2 -> speaker: comicinker -> text: what filesystem are you using on your sd , did you empty the trash ?\nedu_ID: d41e3 -> speaker: rhodry_2409 -> text: my system is in french , i will try to translate\nedu_ID: d41e4 -> speaker: rhodry_2409 -> text: error when open the file : input and output erreor\nedu_ID: d41e5 -> speaker: comicinker -> text: ah , vous parlez en francaise , mais , je ne parlez pas EMOJI . what filesystem ?\nedu_ID: d41e6 -> speaker: rhodry_2409 -> text: yes , i have format the card just before trying tor write on it\nedu_ID: d41e7 -> speaker: comicinker -> text: did you try fsck on it ?\nedu_ID: d41e8 -> speaker: rhodry_2409 -> text: yes in fact i can write on it with gparted live-cd but no with ubuntu .',
#  "edu_ID: d42e1 -> speaker: bhavi_bond -> text: channel [ linuxmobile ] does not exist error when i try to register\nedu_ID: d42e2 -> speaker: Answer -> text: that channel does not exist . try another channel .\nedu_ID: d42e3 -> speaker: crane_ -> text: so have you joined that channel ?\nedu_ID: d42e4 -> speaker: crane_ -> text: and you are trying to register it ?\nedu_ID: d42e5 -> speaker: crane_ -> text: i do n't think this is an ubuntu problem .\nedu_ID: d42e6 -> speaker: numan -> text: can you tell me how to get the media codecs for totem mplayer\nedu_ID: d42e7 -> speaker: crane_ -> text: do not use totem , so i am not real sure",
#  'edu_ID: d43e1 -> speaker: rhodry_2409 -> text: and i have input output errors\nedu_ID: d43e2 -> speaker: comicinker -> text: you can use autocomplete for usernames , punshing in the first letters and hit tab\nedu_ID: d43e3 -> speaker: comicinker -> text: what filesystem are you using on your sd , did you empty the trash ?\nedu_ID: d43e4 -> speaker: rhodry_2409 -> text: error when open the file : input and output erreor\nedu_ID: d43e5 -> speaker: comicinker -> text: ah , vous parlez en francaise , mais , je ne parlez pas EMOJI . what filesystem ?\nedu_ID: d43e6 -> speaker: rhodry_2409 -> text: yes , i have format the card just before trying tor write on it\nedu_ID: d43e7 -> speaker: comicinker -> text: did you try fsck on it ?\nedu_ID: d43e8 -> speaker: rhodry_2409 -> text: yes in fact i can write on it with gparted live-cd but no with ubuntu .',
#  "edu_ID: d44e1 -> speaker: poobird -> text: i wan na see if i can melt my computer\nedu_ID: d44e2 -> speaker: Polysics -> text: not if you want to be asked for the password\nedu_ID: d44e3 -> speaker: Fwb2700 -> text: why are you talking to yourself ? ?\nedu_ID: d44e4 -> speaker: froschi_ -> text: well , you 're doing it wrong :\nedu_ID: d44e5 -> speaker: Polysics -> text: all i need to know is that , reasonably , nothing is changing my password\nedu_ID: d44e6 -> speaker: juk -> text: well im not from nz\nedu_ID: d44e7 -> speaker: seidos -> text: already talking in ubuntu-offtopic . where else ?\nedu_ID: d44e8 -> speaker: ubottu -> text: the guidelines for using the ubuntu channels can be found here : URL",
#  "edu_ID: d45e1 -> speaker: aikInsaan -> text: there is no option for unityand i have tried these optionsunity is n't one of them\nedu_ID: d45e2 -> speaker: Phr3d13 -> text: i believe ubuntu if the 'unity ' option\nedu_ID: d45e3 -> speaker: aikInsaan -> text: that 's what i thought.turns out it is n't\nedu_ID: d45e4 -> speaker: Phr3d13 -> text: if you do n't have a good enough FILEPATH right drivers the unity interface wo n't show up\nedu_ID: d45e5 -> speaker: aikInsaan -> text: i read somewhere that there are some hardware requirements\nedu_ID: d45e6 -> speaker: aikInsaan -> text: hmmis there a way around that\nedu_ID: d45e7 -> speaker: Phr3d13 -> text: do you still have the default drivers for your video card ?",
#  "edu_ID: d46e1 -> speaker: camer0ff -> text: hyper_ch thats pretty much it.. i can send you the entire lot of info if you like ?\nedu_ID: d46e2 -> speaker: Linux_Galore -> text: i remember 5.10 used to have dns issues with some routers , 6.06 fixed it all\nedu_ID: d46e3 -> speaker: camer0ff -> text: cool well we will see with the xubuntu 6.10 version EMOJI\nedu_ID: d46e4 -> speaker: Linux_Galore -> text: 5.10 was very much an experimental release , lots of breakage\nedu_ID: d46e5 -> speaker: gnomefreak -> text: no its not breezy was very stable\nedu_ID: d46e6 -> speaker: Linux_Galore -> text: i had piles of problems with 5.10 , next to none with 6.06\nedu_ID: d46e7 -> speaker: Linux_Galore -> text: most of the issues i had with 6,10 were because of a poor update manager setup\nedu_ID: d46e8 -> speaker: gnomefreak -> text: edgy was the `` experimental '' in some peoples eyes",
#  "edu_ID: d47e1 -> speaker: jokkaa -> text: damnit.. i want to to it throu the network . like windows netsend..\nedu_ID: d47e2 -> speaker: graingert -> text: ask him to ssh into you with urm whatsit and use cowsay `` you suck '' wall\nedu_ID: d47e3 -> speaker: jokkaa -> text: prob is i want to make him irriteade.. cant do that if he agreesEMOJI ,\nedu_ID: d47e4 -> speaker: graingert -> text: pull him off the lan with ettercap-ng\nedu_ID: d47e5 -> speaker: nite_johnboy -> text: thanks for terminal command post for kde install - appreciate it .\nedu_ID: d47e6 -> speaker: Wolf23 -> text: is it make sounds when click from mouse ?\nedu_ID: d47e7 -> speaker: graingert -> text: is it not make sounds it is make visual",
#  "edu_ID: d48e1 -> speaker: technodude -> text: can you build a tar file on a debian based distro ?\nedu_ID: d48e2 -> speaker: cafuego -> text: of course . just make sure you use .FILEPATH -- prefix=FILEPATH\nedu_ID: d48e3 -> speaker: linux-rulz -> text: yes , i do it all the time with things like mplayer and ffmpe\nedu_ID: d48e4 -> speaker: predaeus -> text: t 's a alcatel usb speedtouch\nedu_ID: d48e5 -> speaker: cafuego -> text: probably a badly ported driver , then .\nedu_ID: d48e6 -> speaker: cafuego -> text: can you swap it over for an ethernet one ?\nedu_ID: d48e7 -> speaker: predaeus -> text: no should and must work with usb\nedu_ID: d48e8 -> speaker: cafuego -> text: no , alcatel have provided a driver which does n't work under 64bit kernels , it seems .",
#  'edu_ID: d49e1 -> speaker: EvilZx -> text: someone else is downloading something so.. yeah .\nedu_ID: d49e2 -> speaker: _Zeus_ -> text: now go to terminal , type sudo nvidia-xconfig\nedu_ID: d49e3 -> speaker: Orbixx -> text: sometimes it will prompt me again for the passphrase .\nedu_ID: d49e4 -> speaker: _Zeus_ -> text: and do you put it in ?\nedu_ID: d49e5 -> speaker: _Zeus_ -> text: did it say that it did it ?\nedu_ID: d49e6 -> speaker: _Zeus_ -> text: cool , now press ctrlaltdel and log back in\nedu_ID: d49e7 -> speaker: dtech -> text: worked like a charm tnx ! just hope the mod fixes the issue !',
#  "edu_ID: d50e1 -> speaker: earthen -> text: it is possable that your blue tooth hard ware is not working\nedu_ID: d50e2 -> speaker: fuzzy_logic -> text: could be.. but its just the standard hardware that was in my notebook when i bought it\nedu_ID: d50e3 -> speaker: earthen -> text: try `` sudo hciconfig hci0 inqmode 0 ''\nedu_ID: d50e4 -> speaker: fuzzy_logic -> text: ca n't get device info : no such device\nedu_ID: d50e5 -> speaker: earthen -> text: i mean ( sudo hidd -- search ) sorry\nedu_ID: d50e6 -> speaker: fuzzy_logic -> text: it does n't work for me..\nedu_ID: d50e7 -> speaker: earthen -> text: did it at least say it was searching\nedu_ID: d50e8 -> speaker: earthen -> text: ok so it was working then i think anyway lol\nedu_ID: d50e9 -> speaker: earthen -> text: do you have anything else with blue tooth that you can try other then your phone\nedu_ID: d50e10 -> speaker: earthen -> text: darn that mean it was n't working",
#  "edu_ID: d51e1 -> speaker: noone -> text: can some one help me with linux\nedu_ID: d51e2 -> speaker: warpforge -> text: what do you want to do ?\nedu_ID: d51e3 -> speaker: _jason -> text: you 're going to have to be more specific . just state your problem .\nedu_ID: d51e4 -> speaker: Ng -> text: everybody here is using ubuntu , just ask your question\nedu_ID: d51e5 -> speaker: tech9iner -> text: hello ? .. ahem.. you are in ubuntu..\nedu_ID: d51e6 -> speaker: ubotu -> text: did you get hit by a windmill ? i do n't know , could you explain it ?\nedu_ID: d51e7 -> speaker: _jason -> text: tell tech9iner about msg the bot\nedu_ID: d51e8 -> speaker: guillem101 -> text: how do i check ubotu messg ?\nedu_ID: d51e9 -> speaker: _jason -> text: what client are you using for irc ?",
#  "edu_ID: d52e1 -> speaker: KillerOrca -> text: bridge [ 192.168.2.2 ] 22 ( ssh ) : connection refused\nedu_ID: d52e2 -> speaker: kthef -> text: you used the ip address ?\nedu_ID: d52e3 -> speaker: KillerOrca -> text: yeah , i used the ip that i type in to access the client 's web settings\nedu_ID: d52e4 -> speaker: kthef -> text: nc -v -w2 -z ipaddress 22\nedu_ID: d52e5 -> speaker: KillerOrca -> text: here was the nmap result : interesting ports on 192.168.1.1 :\nedu_ID: d52e6 -> speaker: KillerOrca -> text: on my machine or the router or both ?\nedu_ID: d52e7 -> speaker: kthef -> text: the bridge to be more specific you may lose that functionality after you make it a bridge\nedu_ID: d52e8 -> speaker: KillerOrca -> text: no that was the router not bridge that i nmaped maybe i need to enable on both ?\nedu_ID: d52e9 -> speaker: kthef -> text: no , i think ssh server does n't work when you put it in bridge mode",
#  "edu_ID: d53e1 -> speaker: Maynel -> text: delete partitions and make one new partition and install ubuntu on it\nedu_ID: d53e2 -> speaker: schnuffle -> text: coose manual partition and adjust as you want\nedu_ID: d53e3 -> speaker: erUSUL -> text: just create a new partiton table - add a single partition - format - done\nedu_ID: d53e4 -> speaker: JTS000ID_ -> text: yeah pidstat is what i was looking for..sweet..\nedu_ID: d53e5 -> speaker: pcpower -> text: already looked , there is n't one that works on amd64\nedu_ID: d53e6 -> speaker: faliva -> text: it 's ntfs , if you did n't read that . forgot to hilight you\nedu_ID: d53e7 -> speaker: erUSUL -> text: shouild be aviable for all users by default .\nedu_ID: d53e8 -> speaker: faliva -> text: yes , installing hal did it . now it works . thank you",
#  'edu_ID: d54e1 -> speaker: JuJuBee_ -> text: that i use between linux and windows\nedu_ID: d54e2 -> speaker: nit-wit -> text: did you mount it with fstab ? give us a pastebin of the fstab that is probably it eh.EMOJI\nedu_ID: d54e3 -> speaker: zykotick9 -> text: umask are subtracted , so your other group has no permission\nedu_ID: d54e4 -> speaker: ikonia -> text: what ever permissions you feel fit\nedu_ID: d54e5 -> speaker: nit-wit -> text: this is the line FILEPATH FILEPATH ntfs-3g quiet , defaults , locale=en_us.utf8 , umask=0\nedu_ID: d54e6 -> speaker: MrNthDegree -> text: outdated by loads , it has 9.04 as the newest version\nedu_ID: d54e7 -> speaker: SuperMiguel -> text: they are back in 9.04 : s',
#  "edu_ID: d55e1 -> speaker: a111 -> text: the flash player for your browser cy ?\nedu_ID: d55e2 -> speaker: CyborgSmurf -> text: i mean where to create flash stuff\nedu_ID: d55e3 -> speaker: Myrtti -> text: no gui apps , flex is your best bet\nedu_ID: d55e4 -> speaker: sirfilipwork -> text: there was a flexbuilder for linux not sure if its live any more\nedu_ID: d55e5 -> speaker: CyborgSmurf -> text: okay , i will check it out\nedu_ID: d55e6 -> speaker: Myrtti -> text: not commandline , but 'coding ' with text editor\nedu_ID: d55e7 -> speaker: CyborgSmurf -> text: i see thanks , i will search a bit",
#  "edu_ID: d56e1 -> speaker: Nuked -> text: ok likwidoxigen ill reboot and let you know how it goes\nedu_ID: d56e2 -> speaker: Likwidoxigen -> text: who makes the printers ? and they woked before yets ?\nedu_ID: d56e3 -> speaker: Nuked -> text: yes they worked excellently on dapper . they are two hp deskjets\nedu_ID: d56e4 -> speaker: nbx909 -> text: does n't give me the address\nedu_ID: d56e5 -> speaker: Likwidoxigen -> text: the device number shoudl be the adress i.e . FILEPATH\nedu_ID: d56e6 -> speaker: Likwidoxigen -> text: ok let me keep poking\nedu_ID: d56e7 -> speaker: nbx909 -> text: i know but it 's a ups ( battery backup ) device would it be under sda ?\nedu_ID: d56e8 -> speaker: Nuked -> text: i used kde 's add printer wizard , and only samba printers are allowed\nedu_ID: d56e9 -> speaker: Likwidoxigen -> text: i 'd assume so , it still has to access the device\nedu_ID: d56e10 -> speaker: Likwidoxigen -> text: damn do any usb device work ?",
#  "edu_ID: d57e1 -> speaker: frank95com -> text: you dfo n't need any other sources for installing kde\nedu_ID: d57e2 -> speaker: Suara -> text: i cant find the pachage using apt\nedu_ID: d57e3 -> speaker: nickrud -> text: you want the sources to compile all of kde ? !\nedu_ID: d57e4 -> speaker: Suara -> text: no . i was goint to do add an entry from apt-get.org , aptitude update and install it\nedu_ID: d57e5 -> speaker: nickrud -> text: why not just install kubuntu-desktop ? but otherwise , you 'd add that deb line to FILEPATH\nedu_ID: d57e6 -> speaker: nickrud -> text: kubuntu-desktop puts kde on your machine . no external sources needed\nedu_ID: d57e7 -> speaker: Suara -> text: i have no result for that using apttitude search\nedu_ID: d57e8 -> speaker: nickrud -> text: you have no kubuntu-desktop ? then your sources.list is fubar 'd .",
#  'edu_ID: d58e1 -> speaker: EvilZx -> text: someone else is downloading something so.. yeah .\nedu_ID: d58e2 -> speaker: _Zeus_ -> text: now go to terminal , type sudo nvidia-xconfig\nedu_ID: d58e3 -> speaker: Orbixx -> text: sometimes it will prompt me again for the passphrase .\nedu_ID: d58e4 -> speaker: _Zeus_ -> text: and do you put it in ?\nedu_ID: d58e5 -> speaker: _Zeus_ -> text: cool , now press ctrlaltdel and log back in\nedu_ID: d58e6 -> speaker: dtech -> text: worked like a charm tnx ! just hope the mod fixes the issue !\nedu_ID: d58e7 -> speaker: _Zeus_ -> text: technically , restart x , not gdm , but same idea',
#  "edu_ID: d59e1 -> speaker: shock -> text: ur not running powerpc are you ?\nedu_ID: d59e2 -> speaker: neighborlee -> text: heh that would be a no EMOJI\nedu_ID: d59e3 -> speaker: tritium -> text: i do n't think we 're all experiencing those problems\nedu_ID: d59e4 -> speaker: ollie -> text: then something about an extended bios functions failing\nedu_ID: d59e5 -> speaker: Peter -> text: if i got the name of the kernel and used apt get -- would it work ?\nedu_ID: d59e6 -> speaker: tritium -> text: but i 've never tried anything like that are all the kernel listed amd64 specific ?\nedu_ID: d59e7 -> speaker: tritium -> text: i think you 'll have to download off an archive then , to get it",
#  "edu_ID: d60e1 -> speaker: earthen -> text: it is possable that your blue tooth hard ware is not working\nedu_ID: d60e2 -> speaker: fuzzy_logic -> text: could be.. but its just the standard hardware that was in my notebook when i bought it\nedu_ID: d60e3 -> speaker: earthen -> text: try `` sudo hciconfig hci0 inqmode 0 ''\nedu_ID: d60e4 -> speaker: fuzzy_logic -> text: ca n't get device info : no such device\nedu_ID: d60e5 -> speaker: earthen -> text: i mean ( sudo hidd -- search ) sorry\nedu_ID: d60e6 -> speaker: fuzzy_logic -> text: it does n't work for me..\nedu_ID: d60e7 -> speaker: earthen -> text: did it at least say it was searching\nedu_ID: d60e8 -> speaker: earthen -> text: ok so it was working then i think anyway lol\nedu_ID: d60e9 -> speaker: earthen -> text: do you have anything else with blue tooth that you can try other then your phone\nedu_ID: d60e10 -> speaker: earthen -> text: how long did it take to search",
# ...
#  "edu_ID: d82e1 -> speaker: technodude -> text: can you build a tar file on a debian based distro ?\nedu_ID: d82e2 -> speaker: cafuego -> text: of course . just make sure you use .FILEPATH -- prefix=FILEPATH\nedu_ID: d82e3 -> speaker: linux-rulz -> text: yes , i do it all the time with things like mplayer and ffmpe\nedu_ID: d82e4 -> speaker: predaeus -> text: t 's a alcatel usb speedtouch\nedu_ID: d82e5 -> speaker: cafuego -> text: can you swap it over for an ethernet one ?\nedu_ID: d82e6 -> speaker: predaeus -> text: then it would n't run under the x86 live cd also i think .\nedu_ID: d82e7 -> speaker: predaeus -> text: no should and must work with usb\nedu_ID: d82e8 -> speaker: cafuego -> text: no , alcatel have provided a driver which does n't work under 64bit kernels , it seems .",
#  "edu_ID: d83e1 -> speaker: rabiddachshund -> text: `` button 3 '' refers to the mouse scroll wheel , right ?\nedu_ID: d83e2 -> speaker: fyrestrtr -> text: yes , the clicking of the wheel , not scrolling ( that 's 4 and 5 , iirc )\nedu_ID: d83e3 -> speaker: Kworth -> text: i have found it : magic control technology corp\nedu_ID: d83e4 -> speaker: Kworth -> text: now how can i implement the usb card if it has an own entry ?\nedu_ID: d83e5 -> speaker: alexbOrsova -> text: also , internet works just fine from same machine from windows\nedu_ID: d83e6 -> speaker: fyrestrtr -> text: you might need some magic to make it work EMOJI\nedu_ID: d83e7 -> speaker: Kworth -> text: dont be silly , isnt there a way ?\nedu_ID: d83e8 -> speaker: fyrestrtr -> text: no clue .. its a strange one . can you pastebin some logs ?\nedu_ID: d83e9 -> speaker: alexbOrsova -> text: pastebin ? will you be here in a few minutes ?\nedu_ID: d83e10 -> speaker: alexbOrsova -> text: i need to reboot , brb\nedu_ID: d83e11 -> speaker: fyrestrtr -> text: grep eth0 FILEPATH and also dmesg grep eth",
#  "edu_ID: d84e1 -> speaker: earthen -> text: it is possable that your blue tooth hard ware is not working\nedu_ID: d84e2 -> speaker: fuzzy_logic -> text: could be.. but its just the standard hardware that was in my notebook when i bought it\nedu_ID: d84e3 -> speaker: earthen -> text: try `` sudo hciconfig hci0 inqmode 0 ''\nedu_ID: d84e4 -> speaker: fuzzy_logic -> text: ca n't get device info : no such device\nedu_ID: d84e5 -> speaker: earthen -> text: i mean ( sudo hidd -- search ) sorry\nedu_ID: d84e6 -> speaker: fuzzy_logic -> text: it does n't work for me..\nedu_ID: d84e7 -> speaker: earthen -> text: did it at least say it was searching\nedu_ID: d84e8 -> speaker: earthen -> text: ok so it was working then i think anyway lol\nedu_ID: d84e9 -> speaker: earthen -> text: how long did it take to search\nedu_ID: d84e10 -> speaker: earthen -> text: darn that mean it was n't working",
#  "edu_ID: d85e1 -> speaker: qkslvrwolf -> text: how do i get FILEPATH manager to use a different icon for all say , folders ?\nedu_ID: d85e2 -> speaker: _jason -> text: probably need to edit the icon theme\nedu_ID: d85e3 -> speaker: C-O-L-T -> text: help me in installing tovid cause i can not\nedu_ID: d85e4 -> speaker: C-O-L-T -> text: i am following the directions but i still can not\nedu_ID: d85e5 -> speaker: _jason -> text: what error are you getting\nedu_ID: d85e6 -> speaker: C-O-L-T -> text: i will paste to pastebin\nedu_ID: d85e7 -> speaker: _jason -> text: i have no idea about tovidi think you need to install all that stuff it says you are missing\nedu_ID: d85e8 -> speaker: C-O-L-T -> text: should i try the other program\nedu_ID: d85e9 -> speaker: _jason -> text: it 's a dependency anyway so sure\nedu_ID: d85e10 -> speaker: C-O-L-T -> text: i can not get mplayer in synaptic",
#  "edu_ID: d86e1 -> speaker: MohammadAG -> text: replace block with your dev node\nedu_ID: d86e2 -> speaker: blue_pearl -> text: still no luck posting u the output\nedu_ID: d86e3 -> speaker: blue_pearl -> text: here is the output when i ran the comman\nedu_ID: d86e4 -> speaker: blue_pearl -> text: URL here is the output\nedu_ID: d86e5 -> speaker: MohammadAG -> text: i 'm assuming it 's not raid ?\nedu_ID: d86e6 -> speaker: blue_pearl -> text: well first it did not mounted after i did not properly shutdown xp and booted in ubuntu\nedu_ID: d86e7 -> speaker: blue_pearl -> text: i can try but how to run it ?\nedu_ID: d86e8 -> speaker: MohammadAG -> text: i 'm not sure about xp , but vista and 7 had a recovery disc option",
#  "edu_ID: d87e1 -> speaker: techsupport -> text: bluedusk , no , but i dont want to change anything else just that file\nedu_ID: d87e2 -> speaker: BlueEagle -> text: those are the two non-comented lines in it .\nedu_ID: d87e3 -> speaker: BlueEagle -> text: you 'll need to be more spesific .\nedu_ID: d87e4 -> speaker: techsupport -> text: i just need the original contents of FILEPATH , can you provide me with that please sir ?\nedu_ID: d87e5 -> speaker: BlueEagle -> text: i already pasted the two non-commented lines in that file .\nedu_ID: d87e6 -> speaker: techsupport -> text: permission denied lol cant save the file\nedu_ID: d87e7 -> speaker: BlueEagle -> text: that 's because it 's owned by root .\nedu_ID: d87e8 -> speaker: techsupport -> text: with the user that i 'm looged in as\nedu_ID: d87e9 -> speaker: BlueEagle -> text: but you already know that , do n't you ?\nedu_ID: d87e10 -> speaker: techsupport -> text: so how can i login as sudo user now\nedu_ID: d87e11 -> speaker: BlueEagle -> text: you can save the file somewhere else and then copy it as root .",
#  'edu_ID: d88e1 -> speaker: timfrost -> text: gnonmefreak , lightbright , you do not put au . or de . for security.ubuntu.com\nedu_ID: d88e2 -> speaker: lightbright -> text: now you tell us EMOJI so i put au on all except for security ?\nedu_ID: d88e3 -> speaker: timfrost -> text: yes , use au.archive.ubunu.com for breezy , breezy-backports and breezy-updates , but security.ubuntu.com for breezy-security\nedu_ID: d88e4 -> speaker: lightbright -> text: can you pls look at my sources.list now ?\nedu_ID: d88e5 -> speaker: lightbright -> text: can you pls look at my sources.list now and tell me if it look alright to you ?\nedu_ID: d88e6 -> speaker: lightbright -> text: ok ill try update now . brb\nedu_ID: d88e7 -> speaker: lightbright -> text: want me to tell you the results ?\nedu_ID: d88e8 -> speaker: lightbright -> text: no errors now EMOJI you are a genius EMOJI\nedu_ID: d88e9 -> speaker: lightbright -> text: and thanks ! you are great EMOJI',
#  "edu_ID: d89e1 -> speaker: Toma- -> text: but its well worth the wait\nedu_ID: d89e2 -> speaker: woodgrain -> text: i have a decently fast p4 should i still be waiting ?\nedu_ID: d89e3 -> speaker: Toma- -> text: have you run updatedb before ?\nedu_ID: d89e4 -> speaker: woodgrain -> text: no never before -- but it worked and now i have all the files i need .\nedu_ID: d89e5 -> speaker: woodgrain -> text: i do n't have a path to the jre -- do i need to add it ?\nedu_ID: d89e6 -> speaker: Toma- -> text: a path ? ? you compiling somehting ?\nedu_ID: d89e7 -> speaker: woodgrain -> text: do n't need jdk as witnessed by eclipse irc\nedu_ID: d89e8 -> speaker: woodgrain -> text: no i 'm installing this newer ver from the eclipse site .",
#  'edu_ID: d90e1 -> speaker: mrwes -> text: mount shares from ubuntu server FILEPATH FILEPATH cifs credentials=FILEPATH 0 0 you changed this to match your information ?\nedu_ID: d90e2 -> speaker: Doonz -> text: nope didnt here is everything URL\nedu_ID: d90e3 -> speaker: mrwes -> text: there are two in front of your ip\nedu_ID: d90e4 -> speaker: mrwes -> text: and when you did a mkdir you used sharedfiles or server ?\nedu_ID: d90e5 -> speaker: Doonz -> text: the extra must be something pastebin\nedu_ID: d90e6 -> speaker: mrwes -> text: what fs is the share ? ntfs or ext3 ?\nedu_ID: d90e7 -> speaker: Doonz -> text: i can connect to the share through places - connect to server',
#  'edu_ID: d91e1 -> speaker: Tokenekie -> text: how do i search for commands using wildcards ?\nedu_ID: d91e2 -> speaker: fosco_ -> text: many ways , ls FILEPATH or ls FILEPATH for example\nedu_ID: d91e3 -> speaker: lstarnes -> text: or type part of the command then press tab\nedu_ID: d91e4 -> speaker: Tokenekie -> text: are those the only two places to find core commands ?\nedu_ID: d91e5 -> speaker: Tokenekie -> text: omg im so stupid . thanks\nedu_ID: d91e6 -> speaker: fosco_ -> text: yes for most of them use find path -name command to seacrh wherever you want\nedu_ID: d91e7 -> speaker: Tokenekie -> text: yeah , i tried it with whereis but it doesnt let you use wildcards',
#  "edu_ID: d92e1 -> speaker: specialbuddy -> text: well i want to know why i ca n't go into display and fix the resolution size\nedu_ID: d92e2 -> speaker: lowman62 -> text: if you are at a desktop what is your resolution set at ?\nedu_ID: d92e3 -> speaker: lowman62 -> text: are you at the desktop ? or stuck in a cli\nedu_ID: d92e4 -> speaker: lowman62 -> text: if you are at a desktop what is your resolution set at ?\nedu_ID: d92e5 -> speaker: mwe -> text: you _need_ to read the wiki .\nedu_ID: d92e6 -> speaker: lowman62 -> text: what is the monitor that you have ?\nedu_ID: d92e7 -> speaker: mwe -> text: you should then do what it says\nedu_ID: d92e8 -> speaker: mwe -> text: you still need to edit xorg.conf it does n't work correctly",
#  "edu_ID: d93e1 -> speaker: Nuked -> text: ok likwidoxigen ill reboot and let you know how it goes\nedu_ID: d93e2 -> speaker: Likwidoxigen -> text: who makes the printers ? and they woked before yets ?\nedu_ID: d93e3 -> speaker: Nuked -> text: yes they worked excellently on dapper . they are two hp deskjets\nedu_ID: d93e4 -> speaker: nbx909 -> text: does n't give me the address\nedu_ID: d93e5 -> speaker: Likwidoxigen -> text: and they just dont ' print properly ?\nedu_ID: d93e6 -> speaker: Likwidoxigen -> text: the device number shoudl be the adress i.e . FILEPATH\nedu_ID: d93e7 -> speaker: Likwidoxigen -> text: ok let me keep poking\nedu_ID: d93e8 -> speaker: nbx909 -> text: i know but it 's a ups ( battery backup ) device would it be under sda ?\nedu_ID: d93e9 -> speaker: Nuked -> text: i used kde 's add printer wizard , and only samba printers are allowed\nedu_ID: d93e10 -> speaker: Likwidoxigen -> text: damn do any usb device work ?",
#  "edu_ID: d94e1 -> speaker: MohammadAG -> text: replace block with your dev node\nedu_ID: d94e2 -> speaker: blue_pearl -> text: still no luck posting u the output\nedu_ID: d94e3 -> speaker: blue_pearl -> text: here is the output when i ran the comman\nedu_ID: d94e4 -> speaker: blue_pearl -> text: URL here is the output\nedu_ID: d94e5 -> speaker: MohammadAG -> text: i 'm assuming it 's not raid ?\nedu_ID: d94e6 -> speaker: blue_pearl -> text: i can try but how to run it ?\nedu_ID: d94e7 -> speaker: MohammadAG -> text: i 'm not sure about xp , but vista and 7 had a recovery disc option\nedu_ID: d94e8 -> speaker: blue_pearl -> text: ok. will reinstalling the grub2 help in any way ?",
#  "edu_ID: d95e1 -> speaker: gopp -> text: 01:00.0 vga compatible controller : nvidia corporation nv17 [ geforce4 440 go ] ( rev a3 )\nedu_ID: d95e2 -> speaker: FloodBot1 -> text: please do n't flood , use URL to paste , do n't use enter as punctuation .\nedu_ID: d95e3 -> speaker: ziroday -> text: hmm , okay . what version of ubuntu ?\nedu_ID: d95e4 -> speaker: slerder -> text: thanks . is dpkg for installing things ?\nedu_ID: d95e5 -> speaker: ziroday -> text: yep , apt is a frontend to dpkg\nedu_ID: d95e6 -> speaker: ziroday -> text: can you please do sudo apt-get install install pastebinit and then do cat FILEPATH pastebinit\nedu_ID: d95e7 -> speaker: ziroday -> text: okay , you installed the nvidia driver .",
#  "edu_ID: d96e1 -> speaker: vbabiy -> text: yeah now i need to use something like awk to feed it in to vim\nedu_ID: d96e2 -> speaker: kthef -> text: grep pattern files -l list_of_files cat list_of_files xargs vim try that\nedu_ID: d96e3 -> speaker: kthef -> text: you may have to tweak it a little\nedu_ID: d96e4 -> speaker: kthef -> text: make sure you have the right version of the router before you attemptmine is an old version 2\nedu_ID: d96e5 -> speaker: kthef -> text: not you , sorry , should be for killerorca\nedu_ID: d96e6 -> speaker: KillerOrca -> text: have it running , just ca n't ssh to box using it as wireless adaptor\nedu_ID: d96e7 -> speaker: kthef -> text: you set it up as a wireless bridge ?",
#  "edu_ID: d97e1 -> speaker: noone -> text: can some one help me with linux\nedu_ID: d97e2 -> speaker: warpforge -> text: what do you want to do ?\nedu_ID: d97e3 -> speaker: Ng -> text: everybody here is using ubuntu , just ask your question\nedu_ID: d97e4 -> speaker: tech9iner -> text: hello ? .. ahem.. you are in ubuntu..\nedu_ID: d97e5 -> speaker: trappist -> text: please please just skip ahead to your question\nedu_ID: d97e6 -> speaker: ubotu -> text: did you get hit by a windmill ? i do n't know , could you explain it ?\nedu_ID: d97e7 -> speaker: _jason -> text: tell tech9iner about msg the bot\nedu_ID: d97e8 -> speaker: guillem101 -> text: how do i check ubotu messg ?\nedu_ID: d97e9 -> speaker: _jason -> text: what client are you using for irc ?",
#  "edu_ID: d98e1 -> speaker: earthen -> text: it is possable that your blue tooth hard ware is not working\nedu_ID: d98e2 -> speaker: fuzzy_logic -> text: could be.. but its just the standard hardware that was in my notebook when i bought it\nedu_ID: d98e3 -> speaker: earthen -> text: try `` sudo hciconfig hci0 inqmode 0 ''\nedu_ID: d98e4 -> speaker: fuzzy_logic -> text: ca n't get device info : no such device\nedu_ID: d98e5 -> speaker: earthen -> text: i mean ( sudo hidd -- search ) sorry\nedu_ID: d98e6 -> speaker: fuzzy_logic -> text: it does n't work for me..\nedu_ID: d98e7 -> speaker: earthen -> text: ok so it was working then i think anyway lol\nedu_ID: d98e8 -> speaker: earthen -> text: do you have anything else with blue tooth that you can try other then your phone\nedu_ID: d98e9 -> speaker: earthen -> text: how long did it take to search\nedu_ID: d98e10 -> speaker: earthen -> text: darn that mean it was n't working",
#  "edu_ID: d99e1 -> speaker: _Johny -> text: when is feisty planned to be released ?\nedu_ID: d99e2 -> speaker: Gabz -> text: i 've read the 19th aprial\nedu_ID: d99e3 -> speaker: Aaronfromchina -> text: i 'm using 7.04. it 's cool . EMOJI\nedu_ID: d99e4 -> speaker: mbd -> text: yes.. apparently it isnt standard\nedu_ID: d99e5 -> speaker: Aaronfromchina -> text: hope i can be tester some day EMOJI\nedu_ID: d99e6 -> speaker: Gabz -> text: ok i 'm not sure what the header file does or what your actaully trying to program\nedu_ID: d99e7 -> speaker: mbd -> text: im trying to do a `` press the anykey to contineu ''",
#  'edu_ID: d100e1 -> speaker: piyush -> text: i tried sudo synaptic it says host unresolvable\nedu_ID: d100e2 -> speaker: kk_ubuntu -> text: do u also have proxy etc ?\nedu_ID: d100e3 -> speaker: kk_ubuntu -> text: r u running on dhcp or do u have any static ip ?\nedu_ID: d100e4 -> speaker: piyush -> text: i had changed it to static ip but now it is in roaming mode\nedu_ID: d100e5 -> speaker: kk_ubuntu -> text: is it just the synaptec which is not working or the entire internet\nedu_ID: d100e6 -> speaker: kk_ubuntu -> text: try running firefox and go to any website\nedu_ID: d100e7 -> speaker: kk_ubuntu -> text: that will make sure if internet is working or not\nedu_ID: d100e8 -> speaker: kk_ubuntu -> text: some times it is only the problem with synaptec\nedu_ID: d100e9 -> speaker: kk_ubuntu -> text: u will have to remove any system level proxy because ur transactions will try going through that']

# %% [markdown]
# ## Unittest

# %%
class MolweniTest(unittest.TestCase):
    
    def setUp(self):
        print("setting up an object")
        
        '''len(dtcls.raw_data['data']['dialogues']) # 100
        dtcls.raw_data['data']['dialogues'][5]['qas'][19]['id'] # 'e49d165b91894835fd254dfc28d087a9'
        len(dtcls.raw_data['data']['dialogues'][74]['qas']) # 29
        dtcls.raw_data['data']['dialogues'][57]['relations'][1]['type'] # 'Narration'
        len(dtcls.raw_data['data']['dialogues'][9]['relations']) # 10
        dtcls.raw_data['data']['dialogues'][26]['edus'][3]['speaker'] # 'codebrainz'
        len(dtcls.raw_data['data']['dialogues'][86]['edus']) # 11'''
    
    @classmethod
    def setUpClass(cls):
        print("setting up the class")

        
    def testMolweni_into_pandastest(self):
        print("start testing process: Molweni_into_pandas")
        self.mlwn_pnds = Molweni_into_pandas('test-Copy1.json').pandas_data
        self.assertEqual(len(self.mlwn_pnds), 100)
        self.assertEqual(self.mlwn_pnds[5][4][19]['id'], 'e49d165b91894835fd254dfc28d087a9')
        self.assertEqual(len(self.mlwn_pnds[74][4]), 29)
        self.assertEqual(self.mlwn_pnds[57][3][1]['type'], 'Narration')
        self.assertEqual(self.mlwn_pnds[26][2][3]['speaker'], 'codebrainz')   
        self.assertEqual(len(self.mlwn_pnds[86][2]), 11)                
        print("finish testing process: Molweni_into_pandas")
        
    def testMolweni_into_beautiful_pandastest(self):
        print("start testing process: Molweni_into_beautiful_pandas")
        self.mlwn_btfl_pnds = Molweni_into_beautiful_pandas('test-Copy1.json').pandas_data
        self.assertEqual(len(self.mlwn_btfl_pnds), 100)
        self.assertIs(type(self.mlwn_btfl_pnds[95]), list)
        self.assertIs(type(self.mlwn_btfl_pnds[34][2]), str)
        self.assertIs(type(self.mlwn_btfl_pnds[34][3]), str)
        print("finish testing process: Molweni_into_beautiful_pandas")
        
    def testMolweni_into_pandas_QA_editiontest(self):
        print("start testing process: Molweni_into_pandas_QA_edition")
        self.mlwn_pnds_qa = Molweni_into_pandas_QA_edition('test-Copy1.json').pandas_data
        self.assertEqual(len(self.mlwn_pnds_qa), 100)
        self.assertIs(type(self.mlwn_pnds_qa[68]), list)
        self.assertIs(type(self.mlwn_pnds_qa[34][4]), str)
        print("finish testing process: Molweni_into_pandas_QA_edition")
        
    def testMolweni_liststest(self):
        print("start testing process: Molweni_lists")
        self.mlwn_lst_cntxt = Molweni_lists('test-Copy1.json').list_of_contexts
        self.assertEqual(len(self.mlwn_lst_cntxt), 100)
        self.assertIs(type(self.mlwn_lst_cntxt[6]), str)
        self.mlwn_lst_edus = Molweni_lists('test-Copy1.json').list_of_EDUs
        self.assertEqual(len(self.mlwn_lst_edus), 100)
        self.assertIs(type(self.mlwn_lst_edus[44]), str)
        self.mlwn_lst_rltns = Molweni_lists('test-Copy1.json').list_of_relations
        self.assertEqual(len(self.mlwn_lst_rltns), 100)
        self.assertIs(type(self.mlwn_lst_rltns[99]), str)
        self.mlwn_lst_qas = Molweni_lists('test-Copy1.json').list_of_QAs
        self.assertEqual(len(self.mlwn_lst_qas), 100)
        self.assertIs(type(self.mlwn_lst_qas[55]), str)
        print("finish testing process: Molweni_lists")
    
    def tearDown(self):
        print("tearing down")
        
    def doCleanups(self):
        print("cleaning up")

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# testMolweni_into_beautiful_pandastest (__main__.MolweniTest) ... C:\Users\sara7\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ResourceWarning: unclosed file <_io.TextIOWrapper name='test-Copy1.json' mode='r' encoding='utf-8'>
#   after removing the cwd from sys.path.
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ok
# testMolweni_into_pandas_QA_editiontest (__main__.MolweniTest) ...
# setting up the class
# setting up an object
# start testing process: Molweni_into_beautiful_pandas
# Successfully unwraped! You can call in via .pandas_data
# finish testing process: Molweni_into_beautiful_pandas
# tearing down
# cleaning up
# setting up an object
# start testing process: Molweni_into_pandas_QA_edition
# Successfully unwraped! You can call in via .pandas_data
# ok
# testMolweni_into_pandastest (__main__.MolweniTest) ... ok
# testMolweni_liststest (__main__.MolweniTest) ...
# finish testing process: Molweni_into_pandas_QA_edition
# tearing down
# cleaning up
# setting up an object
# start testing process: Molweni_into_pandas
# Successfully unwraped! You can call in via .pandas_data
# finish testing process: Molweni_into_pandas
# tearing down
# cleaning up
# setting up an object
# start testing process: Molweni_lists
# Successfully unwraped! You can call in via .pandas_data
# You can call specific list via .list_of_contexts , .list_of_EDUs , .list_of_relations or .list_of_QAs!
# Successfully unwraped! You can call in via .pandas_data
# You can call specific list via .list_of_contexts , .list_of_EDUs , .list_of_relations or .list_of_QAs!
# Successfully unwraped! You can call in via .pandas_data
# You can call specific list via .list_of_contexts , .list_of_EDUs , .list_of_relations or .list_of_QAs!
# Successfully unwraped! You can call in via .pandas_data
# You can call specific list via .list_of_contexts , .list_of_EDUs , .list_of_relations or .list_of_QAs!
# finish testing process: Molweni_lists
# tearing down
# cleaning up
# ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.589s
#
# OK
